# %% [markdown]
# # Exercise 03 - Columnar Vs Row Storage

# %% [markdown]
# - The columnar storage extension used here:
#     - cstore_fdw by citus_data [https://github.com/citusdata/cstore_fdw](https://github.com/citusdata/cstore_fdw)
# - The data tables are the ones used by citus_data to show the storage extension

# %%
# %load_ext sql
import os
import psycopg2
import pandas

# %% [markdown]
# ## STEP 0 : Connect to the local database where Pagila is loaded
#
# ### Create the database

# %%
#!sudo -u postgres psql -c 'CREATE DATABASE reviews;'

#!wget http://examples.citusdata.com/customer_reviews_1998.csv.gz
#!wget http://examples.citusdata.com/customer_reviews_1999.csv.gz

#!gzip -d customer_reviews_1998.csv.gz 
#!gzip -d customer_reviews_1999.csv.gz 

#!mv customer_reviews_1998.csv /tmp/customer_reviews_1998.csv
#!mv customer_reviews_1999.csv /tmp/customer_reviews_1999.csv

# %% [markdown]
# ### Connect to the database

# %%
DB_ENDPOINT = "127.0.0.1"
DB = 'reviews'
DB_USER = 'student'
DB_PASSWORD = 'student'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

# %sql $conn_string

print(conn_string)
# Out:
# postgresql://student:student@127.0.0.1:5432/reviews

# %% [markdown]
# ## STEP 1 :  Create a table with a normal  (Row) storage & load data
#
# **TODO:** Create a table called customer_reviews_row with the column names contained in the `customer_reviews_1998.csv` and `customer_reviews_1999.csv` files.

# %%
# %%sql
# DROP TABLE IF EXISTS customer_reviews_row;
# CREATE TABLE customer_reviews_row
# (
#     customer_id TEXT,
#     review_date DATE,
#     review_rating INTEGER,
#     review_votes INTEGER,
#     review_helpful_votes INTEGER,
#     product_id TEXT,
#     product_title TEXT,
#     product_sales_rank BIGINT,
#     product_group TEXT,
#     product_category TEXT,
#     product_subcategory TEXT,
#     similar_product_ids CHAR(10)[]
# )

# %% [markdown]
# **TODO:** Use the [COPY statement](https://www.postgresql.org/docs/9.2/sql-copy.html) to populate the tables with the data in the `customer_reviews_1998.csv` and `customer_reviews_1999.csv` files. You can access the files in the `/tmp/` folder.

# %%
#%%sql
#COPY customer_reviews_row FROM '/tmp/customer_reviews_1998.csv' WITH CSV;
#COPY customer_reviews_row FROM '/tmp/customer_reviews_1999.csv' WITH CSV;

# %% [markdown]
# ## STEP 2 :  Create a table with columnar storage & load data
#
# First, load the extension to use columnar storage in Postgres.

# %%
#%%sql

#-- load extension first time after install
#CREATE EXTENSION IF NOT EXISTS citus;

#-- create server object
#CREATE SERVER cstore_server FOREIGN DATA WRAPPER cstore_fdw;

# %% [markdown]
# **TODO:** Create a `FOREIGN TABLE` called `customer_reviews_col` with the column names contained in the `customer_reviews_1998.csv` and `customer_reviews_1999.csv` files.

# %%
# %%sql
# -- create foreign table
# DROP TABLE IF EXISTS customer_reviews_col;
#
# -------------
#
# CREATE EXTENSION IF NOT EXISTS citus;
#
# CREATE TABLE customer_reviews_col
# (
#     customer_id TEXT,
#     review_date DATE,
#     review_rating INTEGER,
#     review_votes INTEGER,
#     review_helpful_votes INTEGER,
#     product_id TEXT,
#     product_title TEXT,
#     product_sales_rank BIGINT,
#     product_group TEXT,
#     product_category TEXT,
#     product_subcategory TEXT,
#     similar_product_ids CHAR(10)[]
# )
# USING columnar;

# %% [markdown]
# **TODO:** Use the [COPY statement](https://www.postgresql.org/docs/9.2/sql-copy.html) to populate the tables with the data in the `customer_reviews_1998.csv` and `customer_reviews_1999.csv` files. You can access the files in the `/tmp/` folder.

# %%
# %%sql
# COPY customer_reviews_col FROM '/tmp/customer_reviews_1998.csv' WITH CSV;
# COPY customer_reviews_col FROM '/tmp/customer_reviews_1999.csv' WITH CSV;

# %% [markdown]
# ## Step 3: Compare perfromamce
#
# Now run the same query on the two tables and compare the run time. Which form of storage is more performant?
#
# **TODO**: Write a query that calculates the average `review_rating` by `product_title` for all reviews in 1995. Sort the data by `review_rating` in descending order. Limit the results to 20.
#
# First run the query on `customer_reviews_row`:

# %%
# %%time
# %%sql

SELECT customer_id, review_date, review_rating, product_id, product_title
FROM customer_reviews_row
ORDER BY review_rating DESC
LIMIT 1000;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/reviews
# 1000 rows affected.
# Wall time: 672 ms
# [('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0312857063', 'Stone of Tears (Sword of Truth, Book 2)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0399236295', 'Redwall (Redwall, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0764104012', "Speed Reading for Business (Barron's Business Success Guides)"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0140254501', 'Bombardiers'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0833552600', 'Redwall'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0399214240', 'Redwall (Redwall, Book 1)'),
#  ('A1BLGX0V45IGHD', datetime.date(1996, 5, 13), 5, '0553283685', 'Hyperion'),
#  ('A3BYX62MZGD423', datetime.date(1996, 5, 13), 5, '0694520004', 'CELEBRATION OF DISCIPLINE'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0486267652', 'Origami Sea Life (Origami)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0815323034', 'The New Arthurian Encyclopedia (Updated Paperback Edition)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0064404536', 'Does God Have a Big Toe? '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0833533924', '2061'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0375408118', 'Snow Falling on Cedars'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0140506330', 'Peter and the Wolf'),
#  ('A2ZASNG957BS76', datetime.date(1996, 5, 12), 5, '0812511816', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0452270804', 'Hardball for Women '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0613026993', 'The Golden Compass (His Dark Materials, Book 1)'),
#  ('A1Y6ZKYW79E79P', datetime.date(1996, 5, 13), 5, '0671877224', 'DEATHKILLER'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0345456327', 'The Belgariad, Vol. 1'),
#  ('AU0UNX6QDOH5U', datetime.date(1996, 5, 14), 5, '0375408118', 'Snow Falling on Cedars'),
#  ('A30TUVFJAQDSQ4', datetime.date(1996, 5, 14), 5, '044022165X', 'The Rainmaker'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '1572700610', 'Third Man (Audio Editions)'),
#  ('A3HQM4EEJ6TLOK', datetime.date(1996, 5, 15), 5, '0691070466', 'Where to Watch Birds in South America'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0060224320', 'Does God Have a Big Toe?'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0140179836', "The Liars' Club"),
#  ('A3O91YY2KJU8B8', datetime.date(1996, 5, 16), 5, '083351895X', 'Watchers'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0679767789', 'Lost In Place '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0375404686', 'Snow Falling on Cedars'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0964010402', 'Project Seek'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0140187537', 'The Winter of Our Discontent (Penguin Twentieth-Century Classics)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '1561004928', 'Moreta'),
#  ('A2ZASNG957BS76', datetime.date(1996, 5, 12), 5, '0312850093', 'The Eye of the World '),
#  ('A2D9G5BJOIOHZL', datetime.date(1996, 5, 12), 5, '0553371304', 'Food of the Gods '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0449911519', 'Secret History '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '037582345X', 'The Golden Compass (His Dark Materials, Book 1)'),
#  ('AMOCE7OQDZEE3', datetime.date(1996, 5, 13), 5, '0446391174', 'Adventures in the Screen Trade'),
#  ('AMOCE7OQDZEE3', datetime.date(1996, 5, 13), 5, '0671877224', 'DEATHKILLER'),
#  ('A14QZ17AH7C4XW', datetime.date(1996, 5, 13), 5, '0385484917', 'Buffett '),
#  ('A3BYX62MZGD423', datetime.date(1996, 5, 13), 5, '0060655372', 'Addiction & Grace'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0345401123', "Your Blues Ain't Like Mine"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0449911616', 'The Crystal Cave (Stewart, Mary, Arthurian Saga, Bk. 1,)'),
#  ('AU0UNX6QDOH5U', datetime.date(1996, 5, 14), 5, '0375404686', 'Snow Falling on Cedars'),
#  ('AU0UNX6QDOH5U', datetime.date(1996, 5, 14), 5, '067976402X', 'Snow Falling on Cedars '),
#  ('ABY1XDBGGYYPI', datetime.date(1996, 5, 14), 5, '042511774X', 'Breathing Lessons'),
#  ('A30TUVFJAQDSQ4', datetime.date(1996, 5, 14), 5, '055371273X', 'The Rainmaker'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0140286829', 'The Third Man'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0553573411', 'Royal Assassin (The Farseer Trilogy, Book 2)'),
#  ('A3HQM4EEJ6TLOK', datetime.date(1996, 5, 15), 5, '0292770634', 'The Birds of South America'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '081257995X', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0886775132', 'Jaran (Jaran)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0440193281', 'Wilderness'),
#  ('AV125RFFR38MB', datetime.date(1996, 5, 16), 5, '0061006629', 'Fatherland'),
#  ('A22DZF3WWZIAX1', datetime.date(1996, 5, 16), 5, '055356112X', 'Once A Hero '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0812532597', 'The Memory of Earth (Homecoming Saga)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0553574132', 'Star Wars'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0553277537', 'Dandelion Wine (Grand Master Editions)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0671885286', 'The Great Reckoning '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0151004439', 'Snow Falling on Cedars'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '067976402X', 'Snow Falling on Cedars '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0679751602', 'Mama Makes Up Her Mind '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0613027698', 'Paula'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '8401423635', 'Paula'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0375806709', 'Phantom Tollbooth'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '1561001309', 'Moreta'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '0515134481', 'Circus of the Damned (Anita Blake Vampire Hunter (Paperback))'),
#  ('A2ZASNG957BS76', datetime.date(1996, 5, 12), 5, '0312850093', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '0312850093', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '1578151325', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1997, 6, 26), 5, 'B00005R08W', 'HTML'),
#  ('ASGC3MUJEJNG', datetime.date(1996, 5, 13), 5, '0446606359', 'Outlaws'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0679410325', 'The Secret History'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0345413350', 'The Golden Compass (His Dark Materials, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '068484477X', 'STONES FROM THE RIVER'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0440418321', 'The Golden Compass (His Dark Materials, Book 1)'),
#  ('AEKJI9I439IHX', datetime.date(1996, 5, 11), 5, '0375757252', 'Kidnapped '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 21), 5, '0553561189', 'Mistress of the Empire'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0679740198', 'Savages'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0345368096', 'Passion of the Western Mind'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 19), 5, '0345394380', 'Only Good Yankee'),
#  ('A3BYX62MZGD423', datetime.date(1996, 5, 13), 5, '0824525035', 'The Rule of Benedict '),
#  ('A16BIP106LPZE7', datetime.date(1996, 5, 13), 5, '0520209028', 'Poles Apart'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 21), 5, '0440145465', 'King Rat'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0399139540', 'Debt of Honor'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0440220467', 'The Commandos'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0618129022', 'The Lord of the Rings (Movie Art Cover)'),
#  ('AU0UNX6QDOH5U', datetime.date(1996, 5, 14), 5, '0151004439', 'Snow Falling on Cedars'),
#  ('AEKJI9I439IHX', datetime.date(1996, 5, 11), 5, '0684176343', "Kidnapped (Scribner's Illustrated Classics)"),
#  ('A1SE2AN6DVM3OU', datetime.date(1995, 7, 21), 5, '0671671642', 'GROWING A BUSINESS'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0140233725', 'The Book of Guys '),
#  ('A30TUVFJAQDSQ4', datetime.date(1996, 5, 14), 5, '0385424736', 'The Rainmaker'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 14), 5, '0679722955', 'The Names (Vintage Contemporaries (Paperback))'),
#  ('A30TUVFJAQDSQ4', datetime.date(1996, 5, 14), 5, '0553502042', 'The Rainmaker'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '1561840033', 'Cosmic Trigger I '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0872862992', 'Resisting the Virtual Life'),
#  ('AXND3TNS0K70R', datetime.date(1996, 5, 15), 5, '0345417976', "A Prayer for Owen Meany (Ballantine Reader's Circle)"),
#  ('A1BOJP7JFJPL0', datetime.date(1996, 5, 15), 5, '0553502204', 'The Horse Whisperer'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0671867296', 'Imzadi (Star Trek'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0471557099', 'The Executive Career Guide for MBAs '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0812511816', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 10), 5, '1854103040', 'The Age of Innocence'),
#  ('AE19K3BWP6YPS', datetime.date(1995, 7, 22), 5, '1573458708', 'Pillar of Light (Work and the Glory, Vol 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0756400953', 'Jaran (Jaran, 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '081257995X', 'The Eye of the World '),
#  ('A3786HUCIYZZ0', datetime.date(1996, 5, 15), 5, '0380713748', 'A Dance at the Slaughterhouse (Matthew Scudder Mysteries (Paperback))'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0399218416', 'A Mother for Choco'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0060391502', 'The Zone'),
#  ('A3O91YY2KJU8B8', datetime.date(1996, 5, 16), 5, '0425107469', 'Watchers'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '052162942X', 'Citizens of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0613181255', "The Liars' Club"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0807281905', 'Redwall'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0345314255', 'The Sword of Shannara'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 14), 5, '0060652950', 'The Great Divorce'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0380977265', 'Dandelion Wine'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '052162942X', 'Citizens of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0440479002', 'The Sign of the Beaver'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '1566091594', "The Non-Designer's Design Book"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0375400699', "Love in the Time of Cholera (Everyman's Library (Cloth))"),
#  ('AQEKRQ5Y0HVMR', datetime.date(1996, 5, 16), 5, '1578151325', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('A1B15BET5TSYDG', datetime.date(1996, 5, 10), 5, '0671703900', 'Rogue Warrior'),
#  ('A1HPIDTM9SRBLP', datetime.date(1995, 7, 18), 5, '0517887290', 'Fingerprints of the Gods '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '4770019653', 'The Silent Cry'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '055306908X', 'The Secret Power Within'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0060927208', 'Paula (Spanish Edition)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0060927216', 'Paula'),
#  ('A145KQ85HIRSYO', datetime.date(1996, 5, 16), 5, '0812968719', 'Investment Biker '),
#  ('A145KQ85HIRSYO', datetime.date(1996, 5, 16), 5, '1558505296', 'Investment Biker'),
#  ('AH7OKBE1Z35YA', datetime.date(1995, 6, 23), 5, '0521469112', 'Invention and Evolution'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 16), 5, '0929661087', 'The Wellness Guide to Lifelong Fitness'),
#  ('AEKJI9I439IHX', datetime.date(1996, 5, 11), 5, '0679850910', 'Kidnapped (Bullseye Step Into Classics)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0689802072', 'Rats Saw God'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '1561004928', 'Moreta'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '0441001971', 'Circus of the Damned (Anita Blake Vampire Hunter (Paperback))'),
#  ('A3SYK92EV28QAC', datetime.date(1996, 5, 12), 5, '1568843224', 'About Face'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '0878301178', 'Impro'),
#  ('A2ZASNG957BS76', datetime.date(1996, 5, 12), 5, '1578151325', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '1565042751', 'Vampire'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 18), 5, '0721681719', 'Textbook of Pediatric Rheumatology'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '081257995X', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 19), 5, '1578151333', 'The Great Hunt (Wheel of Time (Audio))'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '0932633226', 'Quality Software Management'),
#  ('A2YFSHUQB0WOMZ', datetime.date(1996, 5, 13), 5, '0151972036', "Winter's Tale"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0345352459', 'Blue Adept (Book Two'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 30), 5, '0312141440', 'Vurt (Vurt)'),
#  ('AEKJI9I439IHX', datetime.date(1996, 5, 11), 5, '0451525043', 'Kidnapped'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0345410122', 'Maiden Voyage'),
#  ('A2VIQ32Q50IQUY', datetime.date(1996, 5, 13), 5, '0679763899', 'Love Thy Neighbor '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 30), 5, '0812532635', 'The Ships of Earth '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0394815009', 'The Phantom Tollbooth'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0684844729', 'STONES FROM THE RIVER'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 30), 5, '1590073959', 'Lord of Chaos (The Wheel of Time, 6)'),
#  ('AEG94TYVX0HAD', datetime.date(1995, 8, 31), 5, '0345340388', 'Third Eye'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0440401585', 'A Swiftly Tilting Planet (Yearling Books)'),
#  ('A31ZIU6GZVL62J', datetime.date(1995, 9, 3), 5, '0312113706', 'The Official Harvard Student Agencies Bartending Course'),
#  ('A31ZIU6GZVL62J', datetime.date(1995, 9, 3), 5, '0312252862', 'The Official Harvard Student Agencies Bartending Course, 3rd Edition'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 1), 5, '087612225X', 'Wine of the Mystic '),
#  ('AEKJI9I439IHX', datetime.date(1996, 5, 11), 5, '0140434011', 'Kidnapped (Penguin Classics)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0807281808', 'The Golden Compass (His Dark Materials, Book 1)'),
#  ('A3BYX62MZGD423', datetime.date(1996, 5, 13), 5, '0060628391', 'Celebration of Discipline'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0440901588', 'A Swiftly Tilting Planet'),
#  ('AE22YDHSBFYIP', datetime.date(1970, 12, 30), 5, '1551802538', 'Start and Run a Profitable Coffee Bar'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '1559774908', 'Speed Reading'),
#  ('A2DX58COCFR8J2', datetime.date(1995, 8, 2), 5, '038072846X', 'Last Call'),
#  ('A3ROPRO48OQ9D3', datetime.date(1995, 8, 3), 5, '0812922417', '99 Critical Shots in Pool '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '1559273976', 'Longitude '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 6), 5, '1565117077', 'The Lord of the Rings and The Hobbit'),
#  ('ABGCXKLSSKROK', datetime.date(1995, 9, 8), 5, '0140143459', "Liar's Poker"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0395193958', "The Lord of the Rings (Leatherette Collector's Edition)"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0395974682', 'The Lord of the Rings (One Volume Edition)'),
#  ('A12KIXP2DQ2LS4', datetime.date(1995, 9, 8), 5, '067942573X', 'Taltos '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0807209163', 'A Swiftly Tilting Planet'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 6), 5, '0679741143', 'Confessions of a Crap Artist (Of Seville, Calif. '),
#  ('A2A8X9QFFK0GTW', datetime.date(1995, 7, 21), 5, '0613292200', 'Darkness at Sethanon'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0808514083', 'The Crystal Cave'),
#  ('AU0UNX6QDOH5U', datetime.date(1996, 5, 14), 5, '1879960400', 'Junglee Girl'),
#  ('AWZEMOG2NG2Z4', datetime.date(1995, 9, 10), 5, '0765300273', "Wizard's First Rule (Sword of Truth, Book 1)"),
#  ('A1NE6GL9EL18LM', datetime.date(1996, 5, 10), 5, '0679760849', 'The Crossing (The Border Trilogy, V. 2)'),
#  ('AWZEMOG2NG2Z4', datetime.date(1995, 9, 10), 5, '0812548051', "Wizard's First Rule (Sword of Truth, Book 1)"),
#  ('AD1J6VH30R5FX', datetime.date(1995, 8, 6), 5, '042510107X', 'Red Storm Rising'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 21), 5, '0736646000', 'King Rat'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0061054895', 'Soul Music (Discworld Novels (Paperback))'),
#  ('A7TD3MF4H5L7H', datetime.date(1996, 5, 10), 5, '1559273895', 'Psycho-Cybernetics '),
#  ('AU0UNX6QDOH5U', datetime.date(1996, 5, 14), 5, '0062510258', 'Epitaph for a Peach'),
#  ('A3EOIZ0USWYGGJ', datetime.date(1995, 8, 7), 5, '1583140883', 'For the Love of You (Arabesque)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 11), 5, '0848807901', 'Willard & His Bowling Trophies'),
#  ('A7TD3MF4H5L7H', datetime.date(1996, 5, 10), 5, '1559276673', 'The New Psycho-Cybernetics'),
#  ('AMTFJ5ALSIAKX', datetime.date(1995, 7, 21), 5, '0201700735', 'The C++ Programming Language (Special 3rd Edition)'),
#  ('A7TD3MF4H5L7H', datetime.date(1996, 5, 10), 5, '1559276657', 'Psycho-Cybernetics'),
#  ('A24QKYOAVG2Y9T', datetime.date(1996, 5, 14), 5, '0679740325', 'Out of This World (Vintage International)'),
#  ('AZSU24AHOWRBI', datetime.date(1996, 5, 14), 5, '1569310440', 'Maison Ikkoku, Volume 1'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0679727523', 'Duke of Deception (Vintage)'),
#  ('AXND3TNS0K70R', datetime.date(1996, 5, 15), 5, '0345361792', 'A Prayer for Owen Meany'),
#  ('AE22YDHSBFYIP', datetime.date(1970, 12, 30), 5, '1551803542', 'Start and Run a Coffee Bar (Start & Run a)'),
#  ('A1BOJP7JFJPL0', datetime.date(1996, 5, 15), 5, '0440222656', 'The Horse Whisperer'),
#  ('A1BOJP7JFJPL0', datetime.date(1996, 5, 15), 5, '055345594X', 'The Horse Whisperer'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0590477412', 'Deep Trouble (Goosebumps, No 19)'),
#  ('AXND3TNS0K70R', datetime.date(1996, 5, 15), 5, '061303421X', 'A Prayer for Owen Meany'),
#  ('AXND3TNS0K70R', datetime.date(1996, 5, 15), 5, '0679642595', 'A Prayer for Owen Meany (Modern Library)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '1561007773', 'Stone of Tears (Sword of Truth, Book 2)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 21), 5, '1564409945', 'Striper Hot Spots, 2nd '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0312850093', 'The Eye of the World '),
#  ('A4FRRKKT8OZ7J', datetime.date(1995, 9, 20), 5, '0385424728', 'The Chamber'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 20), 5, '0393037010', 'Master and Commander (Aubrey Maturin Series)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 20), 5, '0393307050', 'Master and Commander (Aubrey Maturin Series)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 10), 5, '0806906871', 'The Pond Doctor'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '081257995X', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '1578151325', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 20), 5, '0385333781', 'Player Piano'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0312850093', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0914457748', 'How to Be a Way Cool Grandfather'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0385478348', 'Warfighting'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0932633439', 'Peopleware '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0684868075', 'In His Own Write'),
#  ('A1RH0QIBMLZXR0', datetime.date(1996, 5, 15), 5, '1564142787', 'Think Out of the Box'),
#  ('A3EKM30A94NHUI', datetime.date(1996, 5, 15), 5, '0895263998', 'Inventing the AIDS Virus'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0345358791', '2061'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0399236295', 'Redwall (Redwall, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0441008178', 'Redwall (Redwall, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '044651652X', 'The Bridges of Madison County'),
#  ('ATLV4W7XEJ3L6', datetime.date(1995, 9, 24), 5, '0440220653', 'The Face on the Milk Carton'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 13), 5, '0679734465', 'Valis'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0689827008', 'Dogsong'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0786238585', 'Redwall (Redwall, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '0893662518', 'Moreta'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0060976969', 'My Old Man and the Sea'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '0385285019', 'Illusions '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '0385319258', 'Illusions '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 14), 5, '1878707566', 'Video Demystified, 3rd Edition'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '1565121023', 'My Old Man and the Sea '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '0440204887', 'Illusions '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '052162942X', 'Citizens of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0440216230', 'SIGN OF THE BEAVER'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '048625836X', 'Albinus on Anatomy'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 16), 5, '0130206016', 'UNIX System Administration Handbook (3rd Edition)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '156341029X', 'Stone Butch Blues'),
#  ('A2LJZ5DTMYL1MJ', datetime.date(1996, 5, 16), 5, '1901130177', 'Living and Working in Switzerland, 2e'),
#  ('AQEKRQ5Y0HVMR', datetime.date(1996, 5, 16), 5, '0312850093', 'The Eye of the World '),
#  ('AQEKRQ5Y0HVMR', datetime.date(1996, 5, 16), 5, '0812511816', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('AQEKRQ5Y0HVMR', datetime.date(1996, 5, 16), 5, '081257995X', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 26), 5, '0679603069', 'The World According to Garp (Modern Library)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 23), 5, '0886776155', 'When True Night Falls (Coldfire Trilogy, Book 2)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 26), 5, '0312152175', 'Surfing the Himalayas'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 26), 5, '047130932X', 'Classical Electrodynamics'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0806985534', 'Crafting As A Business'),
#  ('A1P5OWXL0WNLG2', datetime.date(1995, 8, 17), 5, '1880494000', 'Amber Diceless Role-Playing'),
#  ('A3F2X06X49ZHBB', datetime.date(1996, 5, 16), 5, '0452276799', 'Appetites '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0531054659', 'Julius'),
#  ('A3SHQH0853PKHT', datetime.date(1996, 5, 16), 5, '0916554252', 'Master Level Exercise'),
#  ('A1D1BQFAEKS6JB', datetime.date(1996, 5, 16), 5, '0449208133', "Lucifer's Hammer"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 30), 5, '0553277472', 'Zen and the Art of Motorcycle Maintenance'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 20), 5, '0553380966', 'The Diamond Age '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0613290038', 'Paula'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 30), 5, '1559275561', 'Zen and the Art of Motorcycle Maintenance '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 30), 5, '155927557X', 'Zen and the Art of Motorcycle Maintenance '),
#  ('AJM80P8RBWEIA', datetime.date(1995, 7, 24), 5, '0679745688', "Ripley's Game (Vintage Crime/Black Lizard)"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 1), 5, '0805006575', 'The Complete Phantom of the Opera'),
#  ('AJM80P8RBWEIA', datetime.date(1995, 7, 24), 5, '067974438X', 'Tastes of Paradise '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 19), 5, '0812517725', 'The Great Hunt (The Wheel of Time, Book 2)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 15), 5, '0823412199', 'The Life and Death of Crazy Horse'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 15), 5, '0822313405', 'Terminal Identity'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 3), 5, '067188428X', "R L'S DREAM"),
#  ('A3FCRCETQBNMB8', datetime.date(1995, 10, 4), 5, '0679735771', 'American Psycho (Vintage Contemporaries)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 24), 5, '0812885619', 'Nazi Prisoners of War in America'),
#  ('A2YHBPJ5H99UZB', datetime.date(1995, 8, 24), 5, '071463347X', 'Soviet Military Deception in the Second World War (Cass Series on Soviet Military Theory and Practice)'),
#  ('A7TD3MF4H5L7H', datetime.date(1996, 5, 10), 5, '094068747X', 'Psycho-Cybernetics (Audio Renaissance)'),
#  ('A1HPIDTM9SRBLP', datetime.date(1995, 7, 18), 5, '1574531093', 'Fingerprints of the Gods (Alternative History)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 10, 20), 5, '0446605336', 'My Sergei '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 25), 5, '0385469705', 'Just As I Am '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 10), 5, '0141304316', 'The Duplicate (Novel)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 16), 5, '0679728759', 'Blood Meridian '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 10), 5, '0812510127', 'High Flight (McGarvey)'),
#  ('A2ZASNG957BS76', datetime.date(1996, 5, 12), 5, '081257995X', 'The Eye of the World '),
#  ('A2ZASNG957BS76', datetime.date(1996, 5, 12), 5, '081257995X', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 27), 5, '0385479662', 'Crazy Horse and Custer '),
#  ('A2D9G5BJOIOHZL', datetime.date(1996, 5, 12), 5, '0062506528', 'True Hallucinations'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 27), 5, '0195109805', 'Christmas in America'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 10), 5, '0375407936', 'The Border Trilogy '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '0812511816', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 27), 5, '0195042360', 'Inside the Vicious Heart'),
#  ('A3LR85LPXW0AO0', datetime.date(1995, 10, 11), 5, '0262580896', 'The Lost Meaning of Classical Architecture'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 12), 5, '1559631384', 'Renewable Energy'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 12), 5, '1559631384', 'Renewable Energy'),
#  ('APEOCY1IV91YD', datetime.date(1996, 5, 12), 5, '0262691892', 'The War of Desire and Technology at the Close of the Mechanical Age'),
#  ('APKYNAZEZT9YP', datetime.date(1995, 8, 28), 5, '0830642315', 'Build Your Own Electric Vehicle'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0060518049', 'The Secret History'),
#  ('A2YFSHUQB0WOMZ', datetime.date(1996, 5, 13), 5, '0156001942', "Winter's Tale"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 13), 5, '013204918X', 'Data Link Protocols'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 13), 5, '0521277035', 'A First Course in General Relativity'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 13), 5, '0139498761', 'Unix Network Programming'),
#  ('AEI10CA7WT8GF', datetime.date(1995, 8, 30), 5, '0385479565', 'The Hot Zone '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '1569710813', 'Ghost in the Shell (Ghost in the Shell)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 18), 5, '0061020648', 'Guards! Guards! (Discworld Novels (Paperback))'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0804111359', 'Secret History'),
#  ('AEI10CA7WT8GF', datetime.date(1995, 8, 30), 5, '0785775978', 'The Hot Zone'),
#  ('AFJOSL1QAB5H9', datetime.date(1995, 10, 16), 5, '0553272934', 'Hunger of Memory '),
#  ('AFJOSL1QAB5H9', datetime.date(1995, 10, 16), 5, '0785776982', 'Hunger of Memory'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 16), 5, '0871161788', 'How to Write Your Novel'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 17), 5, '0553283685', 'Hyperion'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 18), 5, '0962344788', 'Heavy Light'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 30), 5, '0812513754', 'Lord of Chaos (The Wheel of Time, Book 6)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0394820371', 'The Phantom Tollbooth'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0345409647', 'Interview with the Vampire'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0394498216', 'Interview with the Vampire '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0394556178', 'Interview with the Vampire'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0553290991', 'Nightfall (Bantam Spectra Book)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0679447644', 'Interview With the Vampire'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 30), 5, '0553563513', 'Point of Impact'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0345334647', 'Emerald City of Oz (Wonderful Oz Books)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0486256812', 'The Emerald City of Oz'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0688115586', 'The Emerald City of Oz (Books of Wonder)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '1886354065', 'The Emerald City of Oz'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0914881558', 'The Art of Silk Ribbon Embroidery'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0914881930', 'The Visual Dance'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0064400565', 'Stuart Little'),
#  ('A1IK3NEEHFFO1', datetime.date(1996, 5, 11), 5, '0080408354', 'Aquaculture for Veterinarians, Fish Husbandry and Medicine'),
#  ('AEKJI9I439IHX', datetime.date(1996, 5, 11), 5, '0140366903', 'Kidnapped'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0679893105', 'The Golden Compass (His Dark Materials, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 20), 5, '0886776872', 'Foreigner 2'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0812505182', 'The Magic of Recluce (Recluce series, Book 1)'),
#  ('A2K6OX1TLZPT2O', datetime.date(1995, 9, 6), 5, '0671510053', 'The Shipping News'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 21), 5, '1563890410', 'The Sandman Vol. 4'),
#  ('A2BFFY8AZZE0A5', datetime.date(1995, 10, 21), 5, '0449224503', 'The Gun Ketch (Alan Lewrie Naval Adventures (Paperback))'),
#  ('A2K6OX1TLZPT2O', datetime.date(1995, 9, 6), 5, '068485791X', 'Shipping News '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 20), 5, '0441385540', 'Jhereg'),
#  ('AEKJI9I439IHX', datetime.date(1996, 5, 11), 5, '9626346175', 'Kidnapped'),
#  ('A2K6OX1TLZPT2O', datetime.date(1995, 9, 6), 5, '0743519787', 'The Shipping News'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 22), 5, '0385315147', "Smilla's Sense of Snow"),
#  ('A3P2678CD7BLND', datetime.date(1995, 10, 22), 5, '0824823052', 'The Hikers Guide to Oahu'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 6), 5, '0345340426', 'J.R.R. Tolkien Boxed Set (The Hobbit and The Lord of the Rings)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 18), 5, '0195069056', "Albion's Seed"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0802713122', 'Longitude '),
#  ('A2BFFY8AZZE0A5', datetime.date(1995, 10, 22), 5, '0671760599', 'BLUE HIGHWAYS'),
#  ('A1LNX4Y50UBL1H', datetime.date(1995, 10, 23), 5, '1585742589', 'Monsters of the Sea'),
#  ('A23YEGO8MNIY13', datetime.date(1995, 10, 23), 5, '1563891654', 'The Big Book of Urban Legends (The Big book Series)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 23), 5, '0385190336', 'I Love Lucy Book'),
#  ('A2A8X9QFFK0GTW', datetime.date(1995, 7, 21), 5, '0553263285', 'A Darkness at Sethanon '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 19), 5, '0890878315', 'The Woman Source Catalog & Review'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 24), 5, '0060093668', 'Screwtape Letters, The'),
#  ('A12KIXP2DQ2LS4', datetime.date(1995, 9, 8), 5, '0345404319', 'Taltos'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 24), 5, '0060652934', 'The Screwtape Letters'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 24), 5, '0345340426', 'J.R.R. Tolkien Boxed Set (The Hobbit and The Lord of the Rings)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 24), 5, '0618002251', 'The Hobbit and The Lord of the Rings'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 8), 5, '0312929587', 'Undercurrents'),
#  ('ABGCXKLSSKROK', datetime.date(1995, 9, 8), 5, '0786890088', 'The Angel Maker'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 24), 5, '0471624632', 'Built In Test for VLSI'),
#  ('AH6USH9HAUQ69', datetime.date(1995, 10, 24), 5, '0393321304', 'Hula'),
#  ('A1JBZOGT1FQ0I2', datetime.date(1995, 9, 10), 5, '0441003257', 'Good Omens'),
#  ('A1JBZOGT1FQ0I2', datetime.date(1995, 9, 10), 5, '0441008615', 'Good Omens'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0618260242', 'The Lord of the Rings (Movie Art Cover)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '1559351209', "The Lord of the Rings (Mind's Eye Version)"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 24), 5, '0060652926', 'Mere Christianity'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 24), 5, '0786117818', 'Mere Christianity'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 24), 5, '0805493476', "C.S. Lewis's Mere Christianity (Shepherd's Notes)"),
#  ('AD1J6VH30R5FX', datetime.date(1995, 8, 6), 5, '0399131493', 'Red Storm Rising'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0374373620', 'A Swiftly Tilting Planet'),
#  ('A2XWT86ZGD46JI', datetime.date(1995, 10, 25), 5, '0446602450', 'Spencerville'),
#  ('A2XWT86ZGD46JI', datetime.date(1995, 10, 25), 5, '0679436642', 'Spencerville'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 25), 5, '1879505274', 'Making Movies Work'),
#  ('AWZEMOG2NG2Z4', datetime.date(1995, 9, 10), 5, '1561005983', "Wizard's First Rule (Bookcassette(r) Edition)"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 10), 5, '0804834148', 'The Ronin'),
#  ('AD1J6VH30R5FX', datetime.date(1995, 8, 6), 5, '0896218856', 'Red Storm Rising (Thorndike Basic)'),
#  ('A148LR46UNYDKM', datetime.date(1995, 9, 11), 5, '0613085744', 'Postmortem (Kay Scarpetta Mysteries (Library))'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 10), 5, '0380728621', "All God's Children"),
#  ('A148LR46UNYDKM', datetime.date(1995, 9, 11), 5, '0671023616', 'Postmortem (Kay Scarpetta Mysteries (Paperback))'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 20), 5, '0441182003', 'Taltos (Vlad Taltos)'),
#  ('A3DW109H2KUWYN', datetime.date(1996, 5, 14), 5, '0765301075', 'The Forge of God'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '1566912164', 'Foghorn Outdoors'),
#  ('A148LR46UNYDKM', datetime.date(1995, 9, 11), 5, '0694522899', 'Postmortem'),
#  ('A2MJS085RNKADS', datetime.date(1995, 10, 27), 5, '0786881046', 'Pulp Fiction'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 28), 5, '0312287569', 'The Seventh Scroll'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 28), 5, '0312957572', 'The Seventh Scroll'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 11), 5, '039569454X', 'Alicia Has a Bad Day'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 28), 5, '0932633021', 'Becoming a Technical Leader'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 7), 5, '0451183339', 'Precipice'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 29), 5, '0891230777', 'Native Texas Plants '),
#  ('AMTFJ5ALSIAKX', datetime.date(1995, 7, 21), 5, '0201889544', 'The C++ Programming Language (3rd Edition)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 30), 5, '0805066152', 'A Sea of Words, Third Edition'),
#  ('ABY1XDBGGYYPI', datetime.date(1996, 5, 14), 5, '0785799524', 'Breathing Lessons'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0774805412', 'Outline of Classical Chinese Grammar'),
#  ('A13MK45BXI17ZW', datetime.date(1995, 8, 8), 5, '0881791326', 'The Elements of Typographic Style'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 30), 5, '0060528370', "A People's History of the United States "),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 30), 5, '0060528427', "A People's History of the United States "),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 30), 5, '0060937319', "A People's History of the United States"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0689807775', 'Rats Saw God'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '1561001309', 'Moreta'),
#  ('A1ONHGQ9KTUQDJ', datetime.date(1995, 11, 1), 5, '0345350499', 'The Mists of Avalon'),
#  ('A1ONHGQ9KTUQDJ', datetime.date(1995, 11, 1), 5, '1570422052', 'Mists of Avalon'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0440901588', 'A Swiftly Tilting Planet'),
#  ('A1BOJP7JFJPL0', datetime.date(1996, 5, 15), 5, '0385315236', 'The Horse Whisperer'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 12), 5, '0613034384', 'Citizen of the Galaxy'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0553378597', 'The Orchard '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 2), 5, '0312306180', 'Jenny and the Jaws of Life'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0395338905', 'The Sign of the Beaver'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 12), 5, '0886772400', 'Thendara House (Darkover)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 5), 5, '0312857055', "Wizard's First Rule (Sword of Truth, Book 1)"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 12), 5, '1558612467', 'Native Tongue'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 5), 5, '0765300273', "Wizard's First Rule (Sword of Truth, Book 1)"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 5), 5, '0765346524', "Wizard's First Rule (Sword Of Truth)"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0812548094', 'Stone of Tears (Sword of Truth, Book 2)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 10), 5, '0061056219', 'The Lions of Al-Rassan'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0807209163', 'A Swiftly Tilting Planet'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 21), 5, '0930289560', 'Batman'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0312850093', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 5), 5, '0312152175', 'Surfing the Himalayas'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 5), 5, '0684811766', 'Making the Most of Your Money'),
#  ('A3V22N7A0ZTV8D', datetime.date(1995, 11, 6), 5, '0465026567', 'Gödel, Escher, Bach'),
#  ('A2WESEWGUI56QN', datetime.date(1995, 11, 7), 5, '0380780496', 'Brazzaville Beach'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 7), 5, '0375726632', 'Oldest Living Confederate Widow Tells All '),
#  ('A2BFFY8AZZE0A5', datetime.date(1995, 11, 7), 5, '0819562513', 'Great River'),
#  ('A4FRRKKT8OZ7J', datetime.date(1995, 9, 20), 5, '0440220602', 'The Chamber'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 10), 5, '0914457527', 'Paintball! '),
#  ('A4FRRKKT8OZ7J', datetime.date(1995, 9, 20), 5, '055350228X', 'The Chamber'),
#  ('A1B15BET5TSYDG', datetime.date(1996, 5, 10), 5, '0671799258', 'ROGUE WARRIOR (REISSUE) CASSETTE'),
#  ('A3JLMFF5LC97D0', datetime.date(1995, 11, 10), 5, '0914457551', 'The Complete Book of Golf Games'),
#  ('A4FRRKKT8OZ7J', datetime.date(1995, 9, 20), 5, '0553712233', 'The Chamber'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 10), 5, '0449905179', 'Essays That Worked '),
#  ('AUT0MDXDIOX17', datetime.date(1995, 11, 10), 5, '0784010528', 'The Doors'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 11), 5, '044040942X', 'The Battle for the Castle'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0812533690', 'Stone Song '),
#  ('A2YCWC86RKGC2O', datetime.date(1996, 5, 11), 5, '0898154081', 'Thinkertoys (A Handbook of Business Creativity)'),
#  ('A3MSF3DSNEIOWQ', datetime.date(1996, 5, 15), 5, '0140255125', 'The Woman Who Walked into Doors'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 11), 5, '0140250948', 'In the Lake of the Woods'),
#  ('A34BARDMRDICLF', datetime.date(1996, 5, 15), 5, '1560985410', 'Flying Tigers'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0812511816', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 11), 5, '0735202869', 'Secrets of Power Persuasion'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0471326038', 'The Handbook of Equity Derivatives (Wiley Series in Financial Engineering)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '089997239X', 'Backpacking With Babies and Small Children'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0613003942', 'A Mother for Choco (Goodnight)'),
#  ('A1RH0QIBMLZXR0', datetime.date(1996, 5, 15), 5, '1564141861', 'Think Out of the Box'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 22), 5, '0345386744', 'The Talismans of Shannara (Heritage of Shannara (Paperback))'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0875463460', 'On the Line at Subaru-Isuzu'),
#  ('A2YCWC86RKGC2O', datetime.date(1996, 5, 11), 5, '0446671037', 'Jump Start Your Brain'),
#  ('ATJU8CWCEI17Z', datetime.date(1996, 5, 11), 5, '0312147449', 'The Tao Te Ching of Lao Tzu'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0399214240', 'Redwall (Redwall, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0394815009', 'The Phantom Tollbooth'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0060935820', 'Real Magic'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0441005489', 'Redwall (Redwall, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0446364495', 'The Bridges of Madison County'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 14), 5, '034540288X', 'The Lost World'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 14), 5, '0679419462', 'The Lost World'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 14), 5, '0226871460', 'City of Dreadful Delight '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 14), 5, '1558742956', 'Acts of Kindness'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 24), 5, '0679412034', 'Jim Henson'),
#  ('A399UV6LVAGXK', datetime.date(1995, 8, 14), 5, '0441813046', 'Titan'),
#  ('A2ZASNG957BS76', datetime.date(1996, 5, 16), 5, '0684163225', 'OF WOLVES AND MEN'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0694515558', 'The Zone '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0694521167', 'The Zone'),
#  ('A1B15BET5TSYDG', datetime.date(1996, 5, 10), 5, '0671795937', 'Rogue Warrior'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '0893662518', 'Moreta'),
#  ('AQEKRQ5Y0HVMR', datetime.date(1996, 5, 16), 5, '0880389052', 'Homeland (Forgotten Realms'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 15), 5, '0441328008', 'Heretics of Dune (Dune Chronicles, Book 5)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 15), 5, '0451184963', 'Insomnia'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 15), 5, '0929480376', 'Insomnia'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 15), 5, '0312087101', 'The Book of Kisses '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 15), 5, '0765342537', 'The Dosadi Experiment'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 15), 5, '0312140967', 'The Art of Hugging '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '0385319258', 'Illusions '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0849913411', 'Love Must Be Tough'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '080852125X', 'Sword of Shannara'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 18), 5, '0385336535', 'Final Exit (Third Edition) '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 18), 5, '0440507855', 'Final Exit (Second Edition) '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '1559273054', 'Illusions'),
#  ('A2YCWC86RKGC2O', datetime.date(1996, 5, 11), 5, '0887306667', 'The 22 Immutable Laws of Marketing '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 23), 5, '0886775272', 'Black Sun Rising (The Coldfire Trilogy, Book 1)'),
#  ('A1B15BET5TSYDG', datetime.date(1996, 5, 10), 5, '0671009826', 'Rogue Warrior'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 19), 5, '0922233179', "Ken's Guide to the Bible"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 20), 5, '0140258795', 'Longitude '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 20), 5, '0802713122', 'Longitude '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 20), 5, '1559273976', 'Longitude '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0849962676', 'Love Must Be Tough'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0964010402', 'Project Seek'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0385267746', 'The Design of Everyday Things'),
#  ('A2LJZ5DTMYL1MJ', datetime.date(1996, 5, 16), 5, '1901130169', 'Living and Working in Switzerland'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0140119906', 'Love in the Time of Cholera (Penguin Great Books of the 20th Century)'),
#  ('AQEKRQ5Y0HVMR', datetime.date(1996, 5, 16), 5, '0312850093', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 23), 5, '0966871103', 'A Skiff for All Seasons'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0394561619', 'Love in the Time of Cholera'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0881036358', 'God Emperor of Dune (Dune Chronicles, Book 4)'),
#  ('AQEKRQ5Y0HVMR', datetime.date(1996, 5, 16), 5, '081257995X', 'The Eye of the World '),
#  ('A3EJLAZ05FJNTT', datetime.date(1995, 11, 21), 5, '0373835590', 'These Old Shades'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0312872836', 'Witch Hill'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0192838881', "The Golden Ass (Oxford World's Classics (Paperback))"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 26), 5, '0684824140', 'Dark Sun'),
#  ('A2BFFY8AZZE0A5', datetime.date(1995, 11, 21), 5, '0805211195', 'The Five Books of Moses'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 22), 5, '020156629X', 'Simulating Neural Networks With Mathematica'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 22), 5, '0387953655', 'Quantum Methods with Mathematica'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 22), 5, '0201633469', 'The Protocols (TCP/IP Illustrated, Volume 1)'),
#  ('AUI1QQ91IPNYK', datetime.date(1995, 11, 23), 5, '0671042742', 'The Honourable Schoolboy'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 27), 5, '0684818663', 'Lizard King'),
#  ('A3GZBNM72KUQ6R', datetime.date(1995, 11, 23), 5, '0910311978', 'En Route to Global Occupation'),
#  ('A1251MEGF0INEN', datetime.date(1995, 9, 28), 5, '0865474567', 'Riprap and Cold Mountain Poems'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0393038947', 'When the Air Hits Your Brain'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 25), 5, '0393036979', 'Titanic'),
#  ('A29JG1CS2NDMN5', datetime.date(1995, 11, 25), 5, '0395732611', 'Hatchet'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '086719345X', "Act Like Nothing's Wrong"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 19), 5, '0812509714', 'The Great Hunt '),
#  ('A3F2X06X49ZHBB', datetime.date(1996, 5, 16), 5, '1564554236', 'Appetites'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 30), 5, '0060958324', 'Zen and the Art of Motorcycle Maintenance'),
#  ('A29JG1CS2NDMN5', datetime.date(1995, 11, 25), 5, '0689840926', 'Hatchet'),
#  ('A29JG1CS2NDMN5', datetime.date(1995, 11, 25), 5, '0833508326', 'Hatchet'),
#  ('A29JG1CS2NDMN5', datetime.date(1995, 11, 25), 5, '1581180551', 'Hatchet (Large Print Cornerstone Ser)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 25), 5, '0679729976', 'The Stories of Vladimir Nabokov'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 30), 5, '0688002307', 'Zen and the Art of Motorcycle Maintenance '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 30), 5, '155927378X', 'Zen and the Art of Motorcycle Maintenance'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 20), 5, '1586211145', 'Diamond Age'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 26), 5, '0064470652', 'Witch Baby (Weetzie Bat)'),
#  ('A14FZ2D92F5JNB', datetime.date(1995, 11, 26), 5, '0375725849', 'Perfume '),
#  ('A14FZ2D92F5JNB', datetime.date(1995, 11, 26), 5, '8432215007', 'El perfume'),
#  ('A14FZ2D92F5JNB', datetime.date(1995, 11, 26), 5, '8432215228', 'El perfume'),
#  ('A14FZ2D92F5JNB', datetime.date(1995, 11, 26), 5, '8432215244', 'El Perfume'),
#  ('ACV7V49ZPIF0Z', datetime.date(1995, 11, 26), 5, '0385315236', 'The Horse Whisperer'),
#  ('ACV7V49ZPIF0Z', datetime.date(1995, 11, 26), 5, '0440222656', 'The Horse Whisperer'),
# ...
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 28), 5, '0801858917', 'The Legends of the Jews '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 28), 5, '0801858933', 'The Legends of the Jews '),
#  ('A1A6C34K50HJPK', datetime.date(1996, 1, 28), 5, '006250763X', 'Other Council Fires Were Here Before Ours'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 28), 5, '0195166647', 'The Final Revolution'),
#  ('AUT0MDXDIOX17', datetime.date(1995, 11, 10), 5, '6304286961', 'The Doors'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 20), 5, '0471288969', 'The Guild Handbook of Scientific Illustration'),
#  ('AUT0MDXDIOX17', datetime.date(1995, 11, 10), 5, 'B00004YKSD', 'The Doors (2-Disc Special Edition)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0394820371', 'The Phantom Tollbooth'),
#  ('AUT0MDXDIOX17', datetime.date(1995, 11, 10), 5, 'B00005NB8K', 'The Doors (Special Edition)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 11), 5, '0807281891', 'The Battle for the Castle'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 10), 5, '091445787X', 'Paris for Free (or Extremely Cheap), Revised (for Free Series)'),
#  ('A1IMK11TEFBSX9', datetime.date(1996, 1, 29), 5, '068482471X', "Darwin's Dangerous Idea"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 29), 5, '0571205070', 'Burton on Burton '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 29), 5, '0964242605', 'Know More, Spend Less'),
#  ('A3DR2YQPTIUFN8', datetime.date(1995, 11, 11), 5, '0262560704', 'Effective Cycling'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0880113626', 'Coaching Volleyball Successfully'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 11), 5, '0137993625', 'Secrets of Power Persuasion '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 11), 5, '0823410102', 'The Battle for the Castle'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 30), 5, '0394805720', "There's a Boy in the Girls' Bathroom"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 30), 5, '0394985702', "There's a Boy in the Girls' Bathroom"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 30), 5, '0345419995', "Dave Barry's Greatest Hits"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 11), 5, '0684831309', 'The Codebreakers '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 31), 5, '0312928777', 'If Wishes Were Horses '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 31), 5, '0679760849', 'The Crossing (The Border Trilogy, V. 2)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 31), 5, '0812511816', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 31), 5, '1578151325', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 31), 5, '0471114987', 'Dino-Trekking'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0698113640', 'A Mother for Choco (Paperstar)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 13), 5, '0345340426', 'J.R.R. Tolkien Boxed Set (The Hobbit and The Lord of the Rings)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 1), 5, '0529108356', "God's Word Bible (God's Word Series)"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 1), 5, '0873413741', "Goldmine's Price Guide to Collectible Record Albums (Goldmine Record Album Price Guide)"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 13), 5, '0553375407', 'Ishmael'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 13), 5, '0613080939', 'Ishmael'),
#  ('A1IC6GD32ZX8NH', datetime.date(1995, 8, 12), 5, '1563891336', 'Death'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 13), 5, '0618002251', 'The Hobbit and The Lord of the Rings'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '1559946679', 'Real Magic'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 13), 5, '1565117077', 'The Lord of the Rings and The Hobbit'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '1578151325', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 13), 5, '0312117442', 'The Art of Kissing'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0375806709', 'Phantom Tollbooth'),
#  ('A2NI9PAXZVW8HV', datetime.date(1995, 11, 14), 5, '0399134204', 'The Joy Luck Club'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '039330700X', 'Wonderful Life'),
#  ('A2NI9PAXZVW8HV', datetime.date(1995, 11, 14), 5, '067972768X', 'The Joy Luck Club '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0061091502', 'Real Magic'),
#  ('A2NI9PAXZVW8HV', datetime.date(1995, 11, 14), 5, '0804106304', 'The Joy Luck Club'),
#  ('ATLV4W7XEJ3L6', datetime.date(1995, 9, 24), 5, '038532328X', 'The Face on the Milk Carton'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0345370775', 'Jurassic Park'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0385323301', 'Where the Red Fern Grows'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0394588169', 'Jurassic Park'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0394588304', 'Jurassic Park'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0440412676', 'Where the Red Fern Grows'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0440505712', "The Nitpicker's Guide for Next Generation Trekkers, Vol. 1"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0553274295', 'Where the Red Fern Grows'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0553274295', 'Where the Red Fern Grows'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0590373579', 'Literature Guide'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0590373579', 'Literature Guide'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0671034758', 'The Star Trek Encyclopedia (Star Trek'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0671536079', 'The Star Trek Encyclopedia (Star Trek'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0671536095', 'The Star Trek Encyclopedia'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0807204684', 'Where the Red Fern Grows'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0881030589', 'Where the Red Fern Grows'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0671536109', 'Star Trek Chronology'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0345333926', 'Ringworld'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0440506832', "The Nitpicker's Guide for Classic Trekkers"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 14), 5, '0931580587', "Ain't Nobody's Business If You Do "),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 19), 5, '0312851405', 'The Great Hunt '),
#  ('A3S0206O7KQ9ZW', datetime.date(1995, 7, 23), 5, '0394757688', 'The Long Goodbye (Vintage Crime/Black Lizard)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0807279757', 'Sign of the Beaver'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '0385285019', 'Illusions '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0345378482', 'The Andromeda Strain'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0380731509', 'Wayside School is Falling Down'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0380754843', 'Wayside School is Falling Down'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0385302312', 'Dragonfly in Amber'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0385335970', 'Dragonfly in Amber'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0394415256', 'The Andromeda Strain'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0440215625', 'Dragonfly in Amber'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0553473301', 'Dragonfly in Amber'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0553714511', 'Dragonfly in Amber'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0688078680', 'Wayside School Is Falling Down'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '080720742X', 'Wayside School Is Falling Down'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0385302304', 'Outlander'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0440212561', 'Outlander'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0553473298', 'Outlander'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0553714538', 'Outlander'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0878338020', 'Gardening With Native Plants of the South'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '0440204887', 'Illusions '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 17), 5, '0689718322', 'Dinosaur Dream'),
#  ('A16BTRDAWTVO1R', datetime.date(1997, 6, 3), 5, '089255231X', 'The Shovel and the Loom'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 4), 5, '0399128964', 'Dune (Dune Chronicles (Econo-Clad Hardcover))'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 4), 5, '044100590X', 'Dune'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 4), 5, '0441172717', 'Dune (Dune Chronicles, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 4), 5, '0765342294', "Ender's Game (Ender)"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 4), 5, '0881036366', 'Dune (Dune Chronicles (Econo-Clad Hardcover))'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 4), 5, '1559949570', 'Dune Audio Collection'),
#  ('A30NVIKRN2FWQV', datetime.date(1996, 2, 4), 5, '0679751602', 'Mama Makes Up Her Mind '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 23), 5, '4770017480', 'Handy Japanese'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 19), 5, '0425150429', 'Time Without End'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '1559273054', 'Illusions'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 19), 5, '087542791X', 'To Ride a Silver Broomstick'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '0395911524', 'From Chocolate to Morphine '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '0380714752', 'The True Confessions of Charlotte Doyle (rack)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '053105893X', 'True Confessions Of Charlotte Doyle'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '0452273250', 'Down-Home Wholesome'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '0072487089', 'Drugs, Society and Human Behavior with PowerWeb'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '0452273250', 'Down-Home Wholesome'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '1881558029', "How to Really Love the One You're With!"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '1881558029', "How to Really Love the One You're With!"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '0312929722', 'Miracles Do Happen'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '0892833165', 'Miracles Do Happen'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 6), 5, '1881558029', "How to Really Love the One You're With!"),
#  ('A2YCWC86RKGC2O', datetime.date(1996, 5, 11), 5, '0446671037', 'Jump Start Your Brain'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '034529873X', 'Moreta'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 16), 5, '0131510517', 'UNIX System Administration Handbook (Bk\\CD ROM) (2nd Edition)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '034529873X', 'Moreta'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0192838881', "The Golden Ass (Oxford World's Classics (Paperback))"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0465067107', 'The Design of Everyday Things'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0312857063', 'Stone of Tears (Sword of Truth, Book 2)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 26), 5, '034536676X', 'The World According to Garp'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0374505322', 'The Golden Ass '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0140281649', 'Love in the Time of Cholera (Penguin Great Books of the 20th Century)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0441294677', 'God Emperor of Dune (Dune Chronicles, Book 4)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 26), 5, '0345418018', "The World According to Garp (Ballantine Reader's Circle)"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0812548094', 'Stone of Tears (Sword of Truth, Book 2)'),
#  ('A1P66WOCE3X9ZO', datetime.date(1996, 2, 7), 5, '0061044695', 'Be Buried in the Rain'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 7), 5, '0803294271', 'Heaven Is a Playground'),
#  ('A1P66WOCE3X9ZO', datetime.date(1996, 2, 7), 5, '0425118312', 'Witch'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '1561007773', 'Stone of Tears (Sword of Truth, Book 2)'),
#  ('A1B2S8EFC1PYKE', datetime.date(1995, 9, 26), 5, '0440507545', 'Radical Honesty '),
#  ('AS2FYO2A8WEMB', datetime.date(1996, 2, 8), 5, '0441813046', 'Titan'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 8), 5, '0060675535', 'Keeping Passover '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 8), 5, '0070504563', '201 Killer Cover Letters'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 9), 5, '0451451538', 'Vampire$'),
#  ('A2PLR225N5C0WD', datetime.date(1996, 2, 9), 5, '1563891050', 'The Sandman Vol. 6'),
#  ('A2PLR225N5C0WD', datetime.date(1996, 2, 9), 5, '1563891069', 'Fables and Reflections (Sandman, Book 6)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0374505322', 'The Golden Ass '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 10), 5, '0395716918', 'Piggie Pie!'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 10), 5, '0395866189', 'Piggie Pie!'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 10), 5, '0395900638', 'Piggie Pie!'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 10), 5, '0613036158', 'Piggie Pie!'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 10), 5, '0788190202', 'Bull Cook'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 11), 5, '0060921056', 'Letters from the Earth'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 11), 5, '0848817702', 'Letters from the Earth'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 11), 5, '1590070143', 'Letters from the Earth'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 11), 5, '1931056021', 'Letters from the Earth'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 11), 5, '1931056293', 'Letters from the Earth'),
#  ('A2A9ZIF2NEVS4W', datetime.date(1996, 2, 11), 5, '046509838X', 'Not Out of Africa'),
#  ('A3GZBNM72KUQ6R', datetime.date(1995, 11, 23), 5, '0882791354', 'Global Tyranny...Step by Step'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 12), 5, '155652241X', 'The Mole People'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 12), 5, '0226747875', 'Mystical Languages of Unsaying'),
#  ('A11ETZZ75RJC1W', datetime.date(1996, 2, 12), 5, '0879100737', 'Something Wonderful Right Away'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 12), 5, '0435086294', "The Dramatist's Toolkit"),
#  ('A1X6K8FD5AB8H0', datetime.date(1996, 2, 12), 5, '0764532391', 'Internet Secrets (... Secrets (IDG))'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 12), 5, '0451163931', 'Virtue of Selfishness'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 17), 5, '0946819386', 'Woodturning Wizardry'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 13), 5, '0764110306', 'Guide to a Well-Behaved Parrot'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 13), 5, '1880646021', 'Project Mind'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 13), 5, '1880646021', 'Project Mind'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 13), 5, '1880646021', 'Project Mind'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 13), 5, '1880646021', 'Project Mind'),
#  ('A29JG1CS2NDMN5', datetime.date(1995, 11, 25), 5, '0553470876', 'Hatchet'),
#  ('A29JG1CS2NDMN5', datetime.date(1995, 11, 25), 5, '0590389246', 'Literature Guide'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 17), 5, '0929388054', 'Fireworks'),
#  ('A29JG1CS2NDMN5', datetime.date(1995, 11, 25), 5, '0689808828', 'Hatchet'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 14), 5, '0140250948', 'In the Lake of the Woods'),
#  ('AZHEOTHYGB34T', datetime.date(1996, 2, 14), 5, '0441094996', 'The Cat Who Walks Through Walls'),
#  ('A29JG1CS2NDMN5', datetime.date(1995, 11, 25), 5, '0689826990', 'Hatchet'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 15), 5, '1585742589', 'Monsters of the Sea'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 15), 5, '0140250948', 'In the Lake of the Woods'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 15), 5, '0940350254', 'Three Little Hawaiian Pigs and the Magic Shark'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0441005489', 'Redwall (Redwall, Book 1)')]

# %% [markdown]
#  Then on `customer_reviews_col`:

# %%
# %%time
# %%sql

SELECT customer_id, review_date, review_rating, product_id, product_title
FROM customer_reviews_col
ORDER BY review_rating DESC
LIMIT 1000;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/reviews
# 1000 rows affected.
# Wall time: 804 ms
# [('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0312850093', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0679861564', 'Peter and the Wolf'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0449911616', 'The Crystal Cave (Stewart, Mary, Arthurian Saga, Bk. 1,)'),
#  ('A3HQM4EEJ6TLOK', datetime.date(1996, 5, 15), 5, '0691070466', 'Where to Watch Birds in South America'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0671885286', 'The Great Reckoning '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0670808490', 'Peter and the Wolf'),
#  ('AMOCE7OQDZEE3', datetime.date(1996, 5, 13), 5, '0671877224', 'DEATHKILLER'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0440220467', 'The Commandos'),
#  ('ABY1XDBGGYYPI', datetime.date(1996, 5, 14), 5, '0785799524', 'Breathing Lessons'),
#  ('A3HQM4EEJ6TLOK', datetime.date(1996, 5, 15), 5, '0292770634', 'The Birds of South America'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0471326038', 'The Handbook of Equity Derivatives (Wiley Series in Financial Engineering)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '1566091594', "The Non-Designer's Design Book"),
#  ('A3F2X06X49ZHBB', datetime.date(1996, 5, 16), 5, '0452276799', 'Appetites '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0590386085', 'Peter And The Wolf'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0060518049', 'The Secret History'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0613026993', 'The Golden Compass (His Dark Materials, Book 1)'),
#  ('A3BYX62MZGD423', datetime.date(1996, 5, 13), 5, '0694520004', 'CELEBRATION OF DISCIPLINE'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0399139540', 'Debt of Honor'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0140233725', 'The Book of Guys '),
#  ('A30TUVFJAQDSQ4', datetime.date(1996, 5, 14), 5, '055371273X', 'The Rainmaker'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0312857063', 'Stone of Tears (Sword of Truth, Book 2)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0471557099', 'The Executive Career Guide for MBAs '),
#  ('A34BARDMRDICLF', datetime.date(1996, 5, 15), 5, '1560985410', 'Flying Tigers'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0932633439', 'Peopleware '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0689827008', 'Dogsong'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '156341029X', 'Stone Butch Blues'),
#  ('A2LJZ5DTMYL1MJ', datetime.date(1996, 5, 16), 5, '1901130169', 'Living and Working in Switzerland'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0393038947', 'When the Air Hits Your Brain'),
#  ('A145KQ85HIRSYO', datetime.date(1996, 5, 16), 5, '1558505296', 'Investment Biker'),
#  ('A2XIBS3CKGQHUM', datetime.date(1996, 5, 16), 5, '044921821X', 'Self-Consciousness'),
#  ('A2ZASNG957BS76', datetime.date(1996, 5, 12), 5, '0812511816', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '0932633226', 'Quality Software Management'),
#  ('A1BLGX0V45IGHD', datetime.date(1996, 5, 13), 5, '0553283685', 'Hyperion'),
#  ('AMOCE7OQDZEE3', datetime.date(1996, 5, 13), 5, '0446391174', 'Adventures in the Screen Trade'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0345368096', 'Passion of the Western Mind'),
#  ('A1Y6ZKYW79E79P', datetime.date(1996, 5, 13), 5, '0671877224', 'DEATHKILLER'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '1559774908', 'Speed Reading'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0395974682', 'The Lord of the Rings (One Volume Edition)'),
#  ('AU0UNX6QDOH5U', datetime.date(1996, 5, 14), 5, '1879960400', 'Junglee Girl'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0061054895', 'Soul Music (Discworld Novels (Paperback))'),
#  ('A3DW109H2KUWYN', datetime.date(1996, 5, 14), 5, '0765301075', 'The Forge of God'),
#  ('A30TUVFJAQDSQ4', datetime.date(1996, 5, 14), 5, '0553502042', 'The Rainmaker'),
#  ('AZSU24AHOWRBI', datetime.date(1996, 5, 14), 5, '1569310440', 'Maison Ikkoku, Volume 1'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0140254501', 'Bombardiers'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0553378597', 'The Orchard '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '1561007773', 'Stone of Tears (Sword of Truth, Book 2)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0756400953', 'Jaran (Jaran, 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0914457748', 'How to Be a Way Cool Grandfather'),
#  ('AE22YDHSBFYIP', datetime.date(1970, 12, 30), 5, '1551803542', 'Start and Run a Coffee Bar (Start & Run a)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0440193281', 'Wilderness'),
#  ('AV125RFFR38MB', datetime.date(1996, 5, 16), 5, '0061006629', 'Fatherland'),
#  ('A2ZASNG957BS76', datetime.date(1996, 5, 16), 5, '0684163225', 'OF WOLVES AND MEN'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0833533924', '2061'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0964010402', 'Project Seek'),
#  ('A3SYK92EV28QAC', datetime.date(1996, 5, 12), 5, '1568843224', 'About Face'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0465067107', 'The Design of Everyday Things'),
#  ('AQEKRQ5Y0HVMR', datetime.date(1996, 5, 16), 5, '081257995X', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '4770019653', 'The Silent Cry'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0679751602', 'Mama Makes Up Her Mind '),
#  ('A145KQ85HIRSYO', datetime.date(1996, 5, 16), 5, '0812968719', 'Investment Biker '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0399214240', 'Redwall (Redwall, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0441008178', 'Redwall (Redwall, Book 1)'),
#  ('AEKJI9I439IHX', datetime.date(1996, 5, 11), 5, '0679850910', 'Kidnapped (Bullseye Step Into Classics)'),
#  ('A2ZASNG957BS76', datetime.date(1996, 5, 12), 5, '0312850093', 'The Eye of the World '),
#  ('A2ZASNG957BS76', datetime.date(1996, 5, 12), 5, '1578151325', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('APEOCY1IV91YD', datetime.date(1996, 5, 12), 5, '0262691892', 'The War of Desire and Technology at the Close of the Mechanical Age'),
#  ('A2YFSHUQB0WOMZ', datetime.date(1996, 5, 13), 5, '0151972036', "Winter's Tale"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0452270804', 'Hardball for Women '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0345413350', 'The Golden Compass (His Dark Materials, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0440418321', 'The Golden Compass (His Dark Materials, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0807281808', 'The Golden Compass (His Dark Materials, Book 1)'),
#  ('A3BYX62MZGD423', datetime.date(1996, 5, 13), 5, '0060628391', 'Celebration of Discipline'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0689802072', 'Rats Saw God'),
#  ('A14QZ17AH7C4XW', datetime.date(1996, 5, 13), 5, '0385484917', 'Buffett '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0312850093', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0764104012', "Speed Reading for Business (Barron's Business Success Guides)"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '1559273976', 'Longitude '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0395193958', "The Lord of the Rings (Leatherette Collector's Edition)"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0808514083', 'The Crystal Cave'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '1559351209', "The Lord of the Rings (Mind's Eye Version)"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0486267652', 'Origami Sea Life (Origami)'),
#  ('AU0UNX6QDOH5U', datetime.date(1996, 5, 14), 5, '067976402X', 'Snow Falling on Cedars '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0807209163', 'A Swiftly Tilting Planet'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0453008623', 'Book of Guys Cassette '),
#  ('A30TUVFJAQDSQ4', datetime.date(1996, 5, 14), 5, '0385424736', 'The Rainmaker'),
#  ('A30TUVFJAQDSQ4', datetime.date(1996, 5, 14), 5, '044022165X', 'The Rainmaker'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0774805412', 'Outline of Classical Chinese Grammar'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '1561840033', 'Cosmic Trigger I '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0679727523', 'Duke of Deception (Vintage)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0815323034', 'The New Arthurian Encyclopedia (Updated Paperback Edition)'),
#  ('AXND3TNS0K70R', datetime.date(1996, 5, 15), 5, '0345361792', 'A Prayer for Owen Meany'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0446672289', 'Death of Common Sense '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0553573411', 'Royal Assassin (The Farseer Trilogy, Book 2)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0812548094', 'Stone of Tears (Sword of Truth, Book 2)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '1561004928', 'Moreta'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '1578151325', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0886775132', 'Jaran (Jaran)'),
#  ('A3MSF3DSNEIOWQ', datetime.date(1996, 5, 15), 5, '0140255125', 'The Woman Who Walked into Doors'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 10), 5, '1854103040', 'The Age of Innocence'),
#  ('AE19K3BWP6YPS', datetime.date(1995, 7, 22), 5, '1573458708', 'Pillar of Light (Work and the Glory, Vol 1)'),
#  ('ATJU8CWCEI17Z', datetime.date(1996, 5, 11), 5, '0312147449', 'The Tao Te Ching of Lao Tzu'),
#  ('A3786HUCIYZZ0', datetime.date(1996, 5, 15), 5, '0380713748', 'A Dance at the Slaughterhouse (Matthew Scudder Mysteries (Paperback))'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0399218416', 'A Mother for Choco'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0060391502', 'The Zone'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0441005489', 'Redwall (Redwall, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0613181255', "The Liars' Club"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0812532597', 'The Memory of Earth (Homecoming Saga)'),
#  ('A3O91YY2KJU8B8', datetime.date(1996, 5, 16), 5, '083351895X', 'Watchers'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0345314255', 'The Sword of Shannara'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0679767789', 'Lost In Place '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 14), 5, '0060652950', 'The Great Divorce'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '1569710813', 'Ghost in the Shell (Ghost in the Shell)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '0878301178', 'Impro'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0385267746', 'The Design of Everyday Things'),
#  ('A2LJZ5DTMYL1MJ', datetime.date(1996, 5, 16), 5, '1901130177', 'Living and Working in Switzerland, 2e'),
#  ('AQEKRQ5Y0HVMR', datetime.date(1996, 5, 16), 5, '081257995X', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0375408118', 'Snow Falling on Cedars'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0806985534', 'Crafting As A Business'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '086719345X', "Act Like Nothing's Wrong"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '055306908X', 'The Secret Power Within'),
#  ('A3SHQH0853PKHT', datetime.date(1996, 5, 16), 5, '0916554252', 'Master Level Exercise'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0613290038', 'Paula'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '8401423635', 'Paula'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0140506330', 'Peter and the Wolf'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0399236295', 'Redwall (Redwall, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0441005489', 'Redwall (Redwall, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 17), 5, '0553283685', 'Hyperion'),
#  ('AEKJI9I439IHX', datetime.date(1996, 5, 11), 5, '0140434011', 'Kidnapped (Penguin Classics)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 19), 5, '0345394380', 'Only Good Yankee'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0060935820', 'Real Magic'),
#  ('A2ZASNG957BS76', datetime.date(1996, 5, 12), 5, '081257995X', 'The Eye of the World '),
#  ('A2ZASNG957BS76', datetime.date(1996, 5, 12), 5, '081257995X', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '1565042751', 'Vampire'),
#  ('A2D9G5BJOIOHZL', datetime.date(1996, 5, 12), 5, '0553371304', 'Food of the Gods '),
#  ('AEKJI9I439IHX', datetime.date(1996, 5, 11), 5, '0451525043', 'Kidnapped'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 27), 5, '0195042360', 'Inside the Vicious Heart'),
#  ('ASGC3MUJEJNG', datetime.date(1996, 5, 13), 5, '0446606359', 'Outlaws'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0449911519', 'Secret History '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0679410325', 'The Secret History'),
#  ('A2VIQ32Q50IQUY', datetime.date(1996, 5, 13), 5, '0679763899', 'Love Thy Neighbor '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 30), 5, '0312141440', 'Vurt (Vurt)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '037582345X', 'The Golden Compass (His Dark Materials, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0812511816', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0679893105', 'The Golden Compass (His Dark Materials, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0812505182', 'The Magic of Recluce (Recluce series, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0374373620', 'A Swiftly Tilting Planet'),
#  ('AEKJI9I439IHX', datetime.date(1996, 5, 11), 5, '9626346175', 'Kidnapped'),
#  ('AEKJI9I439IHX', datetime.date(1996, 5, 11), 5, '0684176343', "Kidnapped (Scribner's Illustrated Classics)"),
#  ('AEG94TYVX0HAD', datetime.date(1995, 8, 31), 5, '0345340388', 'Third Eye'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 30), 5, '0553563513', 'Point of Impact'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 21), 5, '1563890356', 'Season of Mists (Sandman, Book 4)'),
#  ('A31ZIU6GZVL62J', datetime.date(1995, 9, 3), 5, '0312252862', 'The Official Harvard Student Agencies Bartending Course, 3rd Edition'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 1), 5, '087612225X', 'Wine of the Mystic '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0440401585', 'A Swiftly Tilting Planet (Yearling Books)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0812533690', 'Stone Song '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0802713122', 'Longitude '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0345401123', "Your Blues Ain't Like Mine"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0345456327', 'The Belgariad, Vol. 1'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 21), 5, '0440145465', 'King Rat'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0618260242', 'The Lord of the Rings (Movie Art Cover)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 6), 5, '0345340426', 'J.R.R. Tolkien Boxed Set (The Hobbit and The Lord of the Rings)'),
#  ('A3ROPRO48OQ9D3', datetime.date(1995, 8, 3), 5, '0812922417', '99 Critical Shots in Pool '),
#  ('AU0UNX6QDOH5U', datetime.date(1996, 5, 14), 5, '0375408118', 'Snow Falling on Cedars'),
#  ('ABGCXKLSSKROK', datetime.date(1995, 9, 8), 5, '0140143459', "Liar's Poker"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0440901588', 'A Swiftly Tilting Planet'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 18), 5, '0195069056', "Albion's Seed"),
#  ('A2A8X9QFFK0GTW', datetime.date(1995, 7, 21), 5, '0613292200', 'Darkness at Sethanon'),
#  ('ABGCXKLSSKROK', datetime.date(1995, 9, 8), 5, '0786890088', 'The Angel Maker'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 6), 5, '0679741143', 'Confessions of a Crap Artist (Of Seville, Calif. '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 21), 5, '1564409945', 'Striper Hot Spots, 2nd '),
#  ('AD1J6VH30R5FX', datetime.date(1995, 8, 6), 5, '0394298667', 'Red Storm Rising'),
#  ('AU0UNX6QDOH5U', datetime.date(1996, 5, 14), 5, '0062510258', 'Epitaph for a Peach'),
#  ('ABY1XDBGGYYPI', datetime.date(1996, 5, 14), 5, '042511774X', 'Breathing Lessons'),
#  ('AWZEMOG2NG2Z4', datetime.date(1995, 9, 10), 5, '0812548051', "Wizard's First Rule (Sword of Truth, Book 1)"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '1578151325', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 10), 5, '0804834148', 'The Ronin'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 21), 5, '0736646000', 'King Rat'),
#  ('A24QKYOAVG2Y9T', datetime.date(1996, 5, 14), 5, '0679740325', 'Out of This World (Vintage International)'),
#  ('AMTFJ5ALSIAKX', datetime.date(1995, 7, 21), 5, '0201700735', 'The C++ Programming Language (Special 3rd Edition)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0394820371', 'The Phantom Tollbooth'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '1572700610', 'Third Man (Audio Editions)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 11), 5, '039569454X', 'Alicia Has a Bad Day'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0394815009', 'The Phantom Tollbooth'),
#  ('AE22YDHSBFYIP', datetime.date(1970, 12, 30), 5, '1551802538', 'Start and Run a Profitable Coffee Bar'),
#  ('AXND3TNS0K70R', datetime.date(1996, 5, 15), 5, '0345417976', "A Prayer for Owen Meany (Ballantine Reader's Circle)"),
#  ('A1BOJP7JFJPL0', datetime.date(1996, 5, 15), 5, '0440222656', 'The Horse Whisperer'),
#  ('A1BOJP7JFJPL0', datetime.date(1996, 5, 15), 5, '0553502204', 'The Horse Whisperer'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0440401585', 'A Swiftly Tilting Planet (Yearling Books)'),
#  ('AXND3TNS0K70R', datetime.date(1996, 5, 15), 5, '061303421X', 'A Prayer for Owen Meany'),
#  ('AXND3TNS0K70R', datetime.date(1996, 5, 15), 5, '0679642595', 'A Prayer for Owen Meany (Modern Library)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 10), 5, '0812510127', 'High Flight (McGarvey)'),
#  ('A2YCWC86RKGC2O', datetime.date(1996, 5, 11), 5, '0898154081', 'Thinkertoys (A Handbook of Business Creativity)'),
#  ('A2ZASNG957BS76', datetime.date(1996, 5, 12), 5, '0312850093', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '081257995X', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0061091502', 'Real Magic'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 17), 5, '0880385359', 'The Crystal Shard (Forgotten Realms'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0064400565', 'Stuart Little'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0064404536', 'Does God Have a Big Toe? '),
#  ('A4FRRKKT8OZ7J', datetime.date(1995, 9, 20), 5, '0385424728', 'The Chamber'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 20), 5, '0393037010', 'Master and Commander (Aubrey Maturin Series)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 20), 5, '0393307050', 'Master and Commander (Aubrey Maturin Series)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 10), 5, '0806906871', 'The Pond Doctor'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0807209163', 'A Swiftly Tilting Planet'),
#  ('A1B15BET5TSYDG', datetime.date(1996, 5, 10), 5, '0671795937', 'Rogue Warrior'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 11), 5, '044040942X', 'The Battle for the Castle'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0385478348', 'Warfighting'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '089997239X', 'Backpacking With Babies and Small Children'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0684868075', 'In His Own Write'),
#  ('A1RH0QIBMLZXR0', datetime.date(1996, 5, 15), 5, '1564141861', 'Think Out of the Box'),
#  ('A3EKM30A94NHUI', datetime.date(1996, 5, 15), 5, '0895263998', 'Inventing the AIDS Virus'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0399214240', 'Redwall (Redwall, Book 1)'),
#  ('A3O91YY2KJU8B8', datetime.date(1996, 5, 16), 5, '0425107469', 'Watchers'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0446364495', 'The Bridges of Madison County'),
#  ('A22DZF3WWZIAX1', datetime.date(1996, 5, 16), 5, '055356112X', 'Once A Hero '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0694515558', 'The Zone '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0807281905', 'Redwall'),
#  ('ATLV4W7XEJ3L6', datetime.date(1995, 9, 24), 5, '0440220653', 'The Face on the Milk Carton'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 13), 5, '0679734465', 'Valis'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0833552600', 'Redwall'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0060976969', 'My Old Man and the Sea'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0380977265', 'Dandelion Wine'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0553277537', 'Dandelion Wine (Grand Master Editions)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '0385285019', 'Illusions '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '0385319258', 'Illusions '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 14), 5, '1878707566', 'Video Demystified, 3rd Edition'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0684844729', 'STONES FROM THE RIVER'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0394815009', 'The Phantom Tollbooth'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 19), 5, '0312851405', 'The Great Hunt '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0375806709', 'Phantom Tollbooth'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '048625836X', 'Albinus on Anatomy'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 16), 5, '0130206016', 'UNIX System Administration Handbook (3rd Edition)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '0515134481', 'Circus of the Damned (Anita Blake Vampire Hunter (Paperback))'),
#  ('AQEKRQ5Y0HVMR', datetime.date(1996, 5, 16), 5, '0312850093', 'The Eye of the World '),
#  ('AQEKRQ5Y0HVMR', datetime.date(1996, 5, 16), 5, '0812511816', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0151004439', 'Snow Falling on Cedars'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0375404686', 'Snow Falling on Cedars'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0849962676', 'Love Must Be Tough'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '067976402X', 'Snow Falling on Cedars '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 26), 5, '047130932X', 'Classical Electrodynamics'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 27), 5, '0684818663', 'Lizard King'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '068484477X', 'STONES FROM THE RIVER'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0531054659', 'Julius'),
#  ('A3F2X06X49ZHBB', datetime.date(1996, 5, 16), 5, '1564554236', 'Appetites'),
#  ('A1HPIDTM9SRBLP', datetime.date(1995, 7, 18), 5, '0517887290', 'Fingerprints of the Gods '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0060927216', 'Paula'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0613027698', 'Paula'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 30), 5, '0688002307', 'Zen and the Art of Motorcycle Maintenance '),
#  ('A7TD3MF4H5L7H', datetime.date(1996, 5, 10), 5, '1559273895', 'Psycho-Cybernetics '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0140187537', 'The Winter of Our Discontent (Penguin Twentieth-Century Classics)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 30), 5, '155927557X', 'Zen and the Art of Motorcycle Maintenance '),
#  ('AJM80P8RBWEIA', datetime.date(1995, 7, 24), 5, '067974438X', 'Tastes of Paradise '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 1), 5, '0805006575', 'The Complete Phantom of the Opera'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 1), 5, '0805017224', 'The Complete Phantom of the Opera'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 19), 5, '0812509714', 'The Great Hunt '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 19), 5, '0812517725', 'The Great Hunt (The Wheel of Time, Book 2)'),
#  ('AH7OKBE1Z35YA', datetime.date(1995, 6, 23), 5, '0521469112', 'Invention and Evolution'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 10), 5, '0380728621', "All God's Children"),
#  ('A3FCRCETQBNMB8', datetime.date(1995, 10, 4), 5, '0679735771', 'American Psycho (Vintage Contemporaries)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 4), 5, '0887308554', 'Accidental Empires'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 24), 5, '0812885619', 'Nazi Prisoners of War in America'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 25), 5, '0385469691', 'Just As I Am'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '081257995X', 'The Eye of the World '),
#  ('A1NE6GL9EL18LM', datetime.date(1996, 5, 10), 5, '0679760849', 'The Crossing (The Border Trilogy, V. 2)'),
#  ('AEKJI9I439IHX', datetime.date(1996, 5, 11), 5, '0140366903', 'Kidnapped'),
#  ('A1HPIDTM9SRBLP', datetime.date(1995, 7, 18), 5, '1574531093', 'Fingerprints of the Gods (Alternative History)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 18), 5, '0061020648', 'Guards! Guards! (Discworld Novels (Paperback))'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0440216230', 'SIGN OF THE BEAVER'),
#  ('A2D9G5BJOIOHZL', datetime.date(1996, 5, 12), 5, '0062506528', 'True Hallucinations'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '0812511816', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '1578151325', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 27), 5, '0195109805', 'Christmas in America'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 19), 5, '1578151333', 'The Great Hunt (Wheel of Time (Audio))'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 10), 5, '0375407936', 'The Border Trilogy '),
#  ('A1GPWZB753AR0C', datetime.date(1995, 10, 10), 5, '038547525X', 'The Great Game of Business'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0345352459', 'Blue Adept (Book Two'),
#  ('A3LR85LPXW0AO0', datetime.date(1995, 10, 11), 5, '0262580896', 'The Lost Meaning of Classical Architecture'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 12), 5, '1559631384', 'Renewable Energy'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 12), 5, '1559631384', 'Renewable Energy'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 12), 5, '0140435611', 'Domestic Manners of the Americans (Penguin Classics)'),
#  ('AEKJI9I439IHX', datetime.date(1996, 5, 11), 5, '0375757252', 'Kidnapped '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0804111359', 'Secret History'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0345410122', 'Maiden Voyage'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 13), 5, '013204918X', 'Data Link Protocols'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 13), 5, '0521277035', 'A First Course in General Relativity'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 13), 5, '0139498761', 'Unix Network Programming'),
#  ('AEI10CA7WT8GF', datetime.date(1995, 8, 30), 5, '0385479565', 'The Hot Zone '),
#  ('AEI10CA7WT8GF', datetime.date(1995, 8, 30), 5, '0385495226', 'The Hot Zone '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0689807775', 'Rats Saw God'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0679740198', 'Savages'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0679879242', 'The Golden Compass (His Dark Materials, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 30), 5, '0812532635', 'The Ships of Earth '),
#  ('AFJOSL1QAB5H9', datetime.date(1995, 10, 16), 5, '0785776982', 'Hunger of Memory'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 16), 5, '0871161788', 'How to Write Your Novel'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 30), 5, '0312854285', 'Lord of Chaos '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 19), 5, '0890878315', 'The Woman Source Catalog & Review'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 21), 5, '0553561189', 'Mistress of the Empire'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 30), 5, '1590073959', 'Lord of Chaos (The Wheel of Time, 6)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0345409647', 'Interview with the Vampire'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0394498216', 'Interview with the Vampire '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0394556178', 'Interview with the Vampire'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0553290991', 'Nightfall (Bantam Spectra Book)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0679447644', 'Interview With the Vampire'),
#  ('A1YJQG7H0KZ3FD', datetime.date(1995, 10, 18), 5, '091488185X', 'Elegant Stitches'),
#  ('A31ZIU6GZVL62J', datetime.date(1995, 9, 3), 5, '0312113706', 'The Official Harvard Student Agencies Bartending Course'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0486256812', 'The Emerald City of Oz'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0688115586', 'The Emerald City of Oz (Books of Wonder)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '1886354065', 'The Emerald City of Oz'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0914881558', 'The Art of Silk Ribbon Embroidery'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 18), 5, '0914881930', 'The Visual Dance'),
#  ('A1XRTNZBZT6J5T', datetime.date(1995, 10, 19), 5, '0684853949', 'The Man Who Mistook His Wife For A Hat '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 20), 5, '0441385540', 'Jhereg'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 20), 5, '0441001963', 'Orca'),
#  ('A3BYX62MZGD423', datetime.date(1996, 5, 13), 5, '0060655372', 'Addiction & Grace'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 13), 5, '0140258795', 'Longitude '),
#  ('A2K6OX1TLZPT2O', datetime.date(1995, 9, 6), 5, '0671510053', 'The Shipping News'),
#  ('A16BIP106LPZE7', datetime.date(1996, 5, 13), 5, '0520209028', 'Poles Apart'),
#  ('A2K6OX1TLZPT2O', datetime.date(1995, 9, 6), 5, '068485791X', 'Shipping News '),
#  ('A2BFFY8AZZE0A5', datetime.date(1995, 10, 21), 5, '0449224503', 'The Gun Ketch (Alan Lewrie Naval Adventures (Paperback))'),
#  ('A2BFFY8AZZE0A5', datetime.date(1995, 10, 21), 5, '0375405232', 'Post Captain (Aubrey-Maturin (Audio))'),
#  ('A2K6OX1TLZPT2O', datetime.date(1995, 9, 6), 5, '0743225422', 'The Shipping News '),
#  ('A2YCWC86RKGC2O', datetime.date(1996, 5, 11), 5, '0446671037', 'Jump Start Your Brain'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0618129022', 'The Lord of the Rings (Movie Art Cover)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 22), 5, '0385315147', "Smilla's Sense of Snow"),
#  ('A3P2678CD7BLND', datetime.date(1995, 10, 22), 5, '0824823052', 'The Hikers Guide to Oahu'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 22), 5, '0156003880', 'Choices'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 6), 5, '0618002251', 'The Hobbit and The Lord of the Rings'),
#  ('A2A8X9QFFK0GTW', datetime.date(1995, 7, 21), 5, '0553263285', 'A Darkness at Sethanon '),
#  ('AU0UNX6QDOH5U', datetime.date(1996, 5, 14), 5, '0375404686', 'Snow Falling on Cedars'),
#  ('A1LNX4Y50UBL1H', datetime.date(1995, 10, 23), 5, '1585742589', 'Monsters of the Sea'),
#  ('A23YEGO8MNIY13', datetime.date(1995, 10, 23), 5, '1563891654', 'The Big Book of Urban Legends (The Big book Series)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 23), 5, '0385190336', 'I Love Lucy Book'),
#  ('A12KIXP2DQ2LS4', datetime.date(1995, 9, 8), 5, '0345404319', 'Taltos'),
#  ('A12KIXP2DQ2LS4', datetime.date(1995, 9, 8), 5, '067942573X', 'Taltos '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 24), 5, '0060093668', 'Screwtape Letters, The'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 24), 5, '0060652896', 'The Screwtape Letters (Gift Edition)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 8), 5, '0312929587', 'Undercurrents'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 24), 5, '0345340426', 'J.R.R. Tolkien Boxed Set (The Hobbit and The Lord of the Rings)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 24), 5, '0618002251', 'The Hobbit and The Lord of the Rings'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 24), 5, '1565117077', 'The Lord of the Rings and The Hobbit'),
#  ('A1JBZOGT1FQ0I2', datetime.date(1995, 9, 10), 5, '0441003257', 'Good Omens'),
#  ('A1JBZOGT1FQ0I2', datetime.date(1995, 9, 10), 5, '0441008615', 'Good Omens'),
#  ('AH6USH9HAUQ69', datetime.date(1995, 10, 24), 5, '0393321304', 'Hula'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 24), 5, '0151329168', 'The Four Loves'),
#  ('AWZEMOG2NG2Z4', datetime.date(1995, 9, 10), 5, '0312857055', "Wizard's First Rule (Sword of Truth, Book 1)"),
#  ('AWZEMOG2NG2Z4', datetime.date(1995, 9, 10), 5, '0765300273', "Wizard's First Rule (Sword of Truth, Book 1)"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '1566912164', 'Foghorn Outdoors'),
#  ('AD1J6VH30R5FX', datetime.date(1995, 8, 6), 5, '0399131493', 'Red Storm Rising'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 24), 5, '0786117818', 'Mere Christianity'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 24), 5, '0805493476', "C.S. Lewis's Mere Christianity (Shepherd's Notes)"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 24), 5, '0801057744', 'The Collapse of Evolution'),
#  ('AD1J6VH30R5FX', datetime.date(1995, 8, 6), 5, '042510107X', 'Red Storm Rising'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0395338905', 'The Sign of the Beaver'),
#  ('A2XWT86ZGD46JI', datetime.date(1995, 10, 25), 5, '0679436642', 'Spencerville'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 25), 5, '1879505274', 'Making Movies Work'),
#  ('A148LR46UNYDKM', datetime.date(1995, 9, 11), 5, '0613085744', 'Postmortem (Kay Scarpetta Mysteries (Library))'),
#  ('AD1J6VH30R5FX', datetime.date(1995, 8, 6), 5, '0896218856', 'Red Storm Rising (Thorndike Basic)'),
#  ('A148LR46UNYDKM', datetime.date(1995, 9, 11), 5, '0671023616', 'Postmortem (Kay Scarpetta Mysteries (Paperback))'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0374373620', 'A Swiftly Tilting Planet'),
#  ('A148LR46UNYDKM', datetime.date(1995, 9, 11), 5, '0694522813', 'Postmortem'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 7), 5, 'B000002B86', 'Frogstomp'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 26), 5, '0312152175', 'Surfing the Himalayas'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 21), 5, '0930289560', 'Batman'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 14), 5, '0140286829', 'The Third Man'),
#  ('A3EOIZ0USWYGGJ', datetime.date(1995, 8, 7), 5, '1583140883', 'For the Love of You (Arabesque)'),
#  ('A2MJS085RNKADS', datetime.date(1995, 10, 27), 5, '0786881046', 'Pulp Fiction'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 28), 5, '0312287569', 'The Seventh Scroll'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 28), 5, '0312957572', 'The Seventh Scroll'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 7), 5, '0451183339', 'Precipice'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 28), 5, '0932633021', 'Becoming a Technical Leader'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 14), 5, '0679722955', 'The Names (Vintage Contemporaries (Paperback))'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 29), 5, '0891230777', 'Native Texas Plants '),
#  ('AMTFJ5ALSIAKX', datetime.date(1995, 7, 21), 5, '0201889544', 'The C++ Programming Language (3rd Edition)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 30), 5, '0805066152', 'A Sea of Words, Third Edition'),
#  ('A1BOJP7JFJPL0', datetime.date(1996, 5, 15), 5, '0385315236', 'The Horse Whisperer'),
#  ('A13MK45BXI17ZW', datetime.date(1995, 8, 8), 5, '0881791326', 'The Elements of Typographic Style'),
#  ('A1BOJP7JFJPL0', datetime.date(1996, 5, 15), 5, '055345594X', 'The Horse Whisperer'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 30), 5, '0060528370', "A People's History of the United States "),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 30), 5, '0060528427', "A People's History of the United States "),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 30), 5, '0060937319', "A People's History of the United States"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0590477412', 'Deep Trouble (Goosebumps, No 19)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0671867296', 'Imzadi (Star Trek'),
#  ('A1ONHGQ9KTUQDJ', datetime.date(1995, 11, 1), 5, '0345350499', 'The Mists of Avalon'),
#  ('A1ONHGQ9KTUQDJ', datetime.date(1995, 11, 1), 5, '1570422052', 'Mists of Avalon'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 12), 5, '0613034384', 'Citizen of the Galaxy'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '1559946679', 'Real Magic'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 22), 5, '0688119158', 'Break on Through '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0440901588', 'A Swiftly Tilting Planet'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 2), 5, '0312306180', 'Jenny and the Jaws of Life'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0812511816', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '081257995X', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 5), 5, '0312857055', "Wizard's First Rule (Sword of Truth, Book 1)"),
#  ('AE19K3BWP6YPS', datetime.date(1995, 7, 22), 5, '088494770X', 'Pillar of Light'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 5), 5, '0765300273', "Wizard's First Rule (Sword of Truth, Book 1)"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 5), 5, '0765346524', "Wizard's First Rule (Sword Of Truth)"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 18), 5, '0721681719', 'Textbook of Pediatric Rheumatology'),
#  ('A1B15BET5TSYDG', datetime.date(1996, 5, 10), 5, '0671799258', 'ROGUE WARRIOR (REISSUE) CASSETTE'),
#  ('A7TD3MF4H5L7H', datetime.date(1996, 5, 10), 5, '1559276673', 'The New Psycho-Cybernetics'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0060224320', 'Does God Have a Big Toe?'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 5), 5, '0312152175', 'Surfing the Himalayas'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 5), 5, '0684811766', 'Making the Most of Your Money'),
#  ('A3V22N7A0ZTV8D', datetime.date(1995, 11, 6), 5, '0465026567', 'Gödel, Escher, Bach'),
#  ('A2WESEWGUI56QN', datetime.date(1995, 11, 7), 5, '0380780496', 'Brazzaville Beach'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 7), 5, '0375726632', 'Oldest Living Confederate Widow Tells All '),
#  ('A2BFFY8AZZE0A5', datetime.date(1995, 11, 7), 5, '0819562513', 'Great River'),
#  ('A4FRRKKT8OZ7J', datetime.date(1995, 9, 20), 5, '0440220602', 'The Chamber'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 10), 5, '0914457527', 'Paintball! '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 10), 5, '0914457675', 'Beer Games 2, Revised '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 10), 5, '0671682288', 'The Wisdom of Florence Scovel Shinn'),
#  ('A4FRRKKT8OZ7J', datetime.date(1995, 9, 20), 5, '0553712233', 'The Chamber'),
#  ('A3JLMFF5LC97D0', datetime.date(1995, 11, 10), 5, '0914457950', 'The Complete Book of Golf Games, Revised Edition'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 20), 5, '0385333781', 'Player Piano'),
#  ('AUT0MDXDIOX17', datetime.date(1995, 11, 10), 5, '0784010528', 'The Doors'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 20), 5, '0471288969', 'The Guild Handbook of Scientific Illustration'),
#  ('A1B15BET5TSYDG', datetime.date(1996, 5, 10), 5, '0671703900', 'Rogue Warrior'),
#  ('A2YCWC86RKGC2O', datetime.date(1996, 5, 11), 5, '0887306667', 'The 22 Immutable Laws of Marketing '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '1561004928', 'Moreta'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 11), 5, '0140250948', 'In the Lake of the Woods'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0880113626', 'Coaching Volleyball Successfully'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0613003942', 'A Mother for Choco (Goodnight)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0698113640', 'A Mother for Choco (Paperstar)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 11), 5, '0684831309', 'The Codebreakers '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 15), 5, '0875463460', 'On the Line at Subaru-Isuzu'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0140179836', "The Liars' Club"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0345358791', '2061'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0399236295', 'Redwall (Redwall, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 13), 5, '0553375407', 'Ishmael'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0807279757', 'Sign of the Beaver'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0441008178', 'Redwall (Redwall, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '044651652X', 'The Bridges of Madison County'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '052162942X', 'Citizens of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '034529873X', 'Moreta'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '1561001309', 'Moreta'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0694521167', 'The Zone'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0786238585', 'Redwall (Redwall, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 14), 5, '0679419462', 'The Lost World'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 14), 5, '0226871460', 'City of Dreadful Delight '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 14), 5, '1558742956', 'Acts of Kindness'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 24), 5, '0679412034', 'Jim Henson'),
#  ('A399UV6LVAGXK', datetime.date(1995, 8, 14), 5, '0441813046', 'Titan'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '1561001309', 'Moreta'),
#  ('A3S0206O7KQ9ZW', datetime.date(1995, 7, 23), 5, '0394757688', 'The Long Goodbye (Vintage Crime/Black Lizard)'),
#  ('AQEKRQ5Y0HVMR', datetime.date(1996, 5, 16), 5, '0880389052', 'Homeland (Forgotten Realms'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '0893662518', 'Moreta'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '1565121023', 'My Old Man and the Sea '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '052162942X', 'Citizens of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 15), 5, '0441328008', 'Heretics of Dune (Dune Chronicles, Book 5)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 15), 5, '0451184963', 'Insomnia'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 15), 5, '0929480376', 'Insomnia'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 15), 5, '0312087101', 'The Book of Kisses '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 15), 5, '0765342537', 'The Dosadi Experiment'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 15), 5, '0312140967', 'The Art of Hugging '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '0385319258', 'Illusions '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '0440204887', 'Illusions '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0394820371', 'The Phantom Tollbooth'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '0440204887', 'Illusions '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 18), 5, '0440507855', 'Final Exit (Second Edition) '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '1559273054', 'Illusions'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 23), 5, '0886775272', 'Black Sun Rising (The Coldfire Trilogy, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '0849913411', 'Love Must Be Tough'),
#  ('A7TD3MF4H5L7H', datetime.date(1996, 5, 10), 5, '1559276657', 'Psycho-Cybernetics'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 19), 5, '0922233179', "Ken's Guide to the Bible"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 20), 5, '0140258795', 'Longitude '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 20), 5, '0802713122', 'Longitude '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 20), 5, '1559273976', 'Longitude '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 23), 5, '0966871103', 'A Skiff for All Seasons'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '0441001971', 'Circus of the Damned (Anita Blake Vampire Hunter (Paperback))'),
#  ('A7TD3MF4H5L7H', datetime.date(1996, 5, 10), 5, '0671700758', 'Psycho Cybernetics'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0140281649', 'Love in the Time of Cholera (Penguin Great Books of the 20th Century)'),
#  ('AQEKRQ5Y0HVMR', datetime.date(1996, 5, 16), 5, '0312850093', 'The Eye of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0394561619', 'Love in the Time of Cholera'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 23), 5, '0886776155', 'When True Night Falls (Coldfire Trilogy, Book 2)'),
#  ('AQEKRQ5Y0HVMR', datetime.date(1996, 5, 16), 5, '1578151325', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0881036358', 'God Emperor of Dune (Dune Chronicles, Book 4)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 26), 5, '0679603069', 'The World According to Garp (Modern Library)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 26), 5, '0684824140', 'Dark Sun'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0312872836', 'Witch Hill'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0192838881', "The Golden Ass (Oxford World's Classics (Paperback))"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 26), 5, '0312152175', 'Surfing the Himalayas'),
#  ('A2BFFY8AZZE0A5', datetime.date(1995, 11, 21), 5, '0805211195', 'The Five Books of Moses'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 22), 5, '020156629X', 'Simulating Neural Networks With Mathematica'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 22), 5, '0387953655', 'Quantum Methods with Mathematica'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 22), 5, '0201633469', 'The Protocols (TCP/IP Illustrated, Volume 1)'),
#  ('AUI1QQ91IPNYK', datetime.date(1995, 11, 23), 5, '0671042742', 'The Honourable Schoolboy'),
#  ('A1251MEGF0INEN', datetime.date(1995, 9, 28), 5, '0865474567', 'Riprap and Cold Mountain Poems'),
#  ('A3GZBNM72KUQ6R', datetime.date(1995, 11, 23), 5, '0910311978', 'En Route to Global Occupation'),
#  ('A1P5OWXL0WNLG2', datetime.date(1995, 8, 17), 5, '1880494000', 'Amber Diceless Role-Playing'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 17), 5, '0946819386', 'Woodturning Wizardry'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0964010402', 'Project Seek'),
#  ('A29JG1CS2NDMN5', datetime.date(1995, 11, 25), 5, '0395732611', 'Hatchet'),
#  ('A29JG1CS2NDMN5', datetime.date(1995, 11, 25), 5, '0553470876', 'Hatchet'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 17), 5, '0929388054', 'Fireworks'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0060927208', 'Paula (Spanish Edition)'),
#  ('A29JG1CS2NDMN5', datetime.date(1995, 11, 25), 5, '0689826990', 'Hatchet'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 30), 5, '0553277472', 'Zen and the Art of Motorcycle Maintenance'),
#  ('A29JG1CS2NDMN5', datetime.date(1995, 11, 25), 5, '0833508326', 'Hatchet'),
#  ('A29JG1CS2NDMN5', datetime.date(1995, 11, 25), 5, '1581180551', 'Hatchet (Large Print Cornerstone Ser)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 25), 5, '0679729976', 'The Stories of Vladimir Nabokov'),
#  ('AJM80P8RBWEIA', datetime.date(1995, 7, 24), 5, '0679745688', "Ripley's Game (Vintage Crime/Black Lizard)"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 30), 5, '1559275561', 'Zen and the Art of Motorcycle Maintenance '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 20), 5, '1586211145', 'Diamond Age'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 26), 5, '0064470652', 'Witch Baby (Weetzie Bat)'),
#  ('A14FZ2D92F5JNB', datetime.date(1995, 11, 26), 5, '0375725849', 'Perfume '),
#  ('A14FZ2D92F5JNB', datetime.date(1995, 11, 26), 5, '8432215007', 'El perfume'),
#  ('A14FZ2D92F5JNB', datetime.date(1995, 11, 26), 5, '8432215228', 'El perfume'),
#  ('A14FZ2D92F5JNB', datetime.date(1995, 11, 26), 5, '8432215244', 'El Perfume'),
#  ('ACV7V49ZPIF0Z', datetime.date(1995, 11, 26), 5, '0385315236', 'The Horse Whisperer'),
#  ('ACV7V49ZPIF0Z', datetime.date(1995, 11, 26), 5, '0440222656', 'The Horse Whisperer'),
#  ('ACV7V49ZPIF0Z', datetime.date(1995, 11, 26), 5, '055345594X', 'The Horse Whisperer'),
#  ('ACV7V49ZPIF0Z', datetime.date(1995, 11, 26), 5, '0553502204', 'The Horse Whisperer'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 1), 5, '0072300604', 'Readings in Social Theory'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 10, 1), 5, '0812533313', 'The Worthing Saga'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 27), 5, '1587154676', 'Bureau 13'),
# ...
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 11), 5, '0807281891', 'The Battle for the Castle'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 10), 5, '091445787X', 'Paris for Free (or Extremely Cheap), Revised (for Free Series)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '034529873X', 'Moreta'),
#  ('A1IMK11TEFBSX9', datetime.date(1996, 1, 29), 5, '068482471X', "Darwin's Dangerous Idea"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 29), 5, '0571205070', 'Burton on Burton '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 29), 5, '0964242605', 'Know More, Spend Less'),
#  ('A3DR2YQPTIUFN8', datetime.date(1995, 11, 11), 5, '0262560704', 'Effective Cycling'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 11), 5, '0137993625', 'Secrets of Power Persuasion '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 11), 5, '0823410102', 'The Battle for the Castle'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 11), 5, '0735202869', 'Secrets of Power Persuasion'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 30), 5, '0394805720', "There's a Boy in the Girls' Bathroom"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 30), 5, '0394985702', "There's a Boy in the Girls' Bathroom"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 30), 5, '0345419995', "Dave Barry's Greatest Hits"),
#  ('A1RH0QIBMLZXR0', datetime.date(1996, 5, 15), 5, '1564142787', 'Think Out of the Box'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 31), 5, '0312928777', 'If Wishes Were Horses '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 31), 5, '0679760849', 'The Crossing (The Border Trilogy, V. 2)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 31), 5, '0812511816', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 31), 5, '1578151325', 'The Eye of the World (The Wheel of Time, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 1, 31), 5, '0471114987', 'Dino-Trekking'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 13), 5, '0345340426', 'J.R.R. Tolkien Boxed Set (The Hobbit and The Lord of the Rings)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 22), 5, '0345386744', 'The Talismans of Shannara (Heritage of Shannara (Paperback))'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 1), 5, '0529108356', "God's Word Bible (God's Word Series)"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 1), 5, '0873413741', "Goldmine's Price Guide to Collectible Record Albums (Goldmine Record Album Price Guide)"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 13), 5, '0613080939', 'Ishmael'),
#  ('A1IC6GD32ZX8NH', datetime.date(1995, 8, 12), 5, '1563891336', 'Death'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 13), 5, '0618002251', 'The Hobbit and The Lord of the Rings'),
#  ('A2YCWC86RKGC2O', datetime.date(1996, 5, 11), 5, '0446671037', 'Jump Start Your Brain'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 13), 5, '1565117077', 'The Lord of the Rings and The Hobbit'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 11), 5, '0440479002', 'The Sign of the Beaver'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 13), 5, '0312117442', 'The Art of Kissing'),
#  ('A2YCWC86RKGC2O', datetime.date(1996, 5, 11), 5, '1559947608', '22 Immutable Laws of Marketing'),
#  ('A2NI9PAXZVW8HV', datetime.date(1995, 11, 14), 5, '0399134204', 'The Joy Luck Club'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 20), 5, '039330700X', 'Wonderful Life'),
#  ('A2NI9PAXZVW8HV', datetime.date(1995, 11, 14), 5, '067972768X', 'The Joy Luck Club '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 12), 5, '0893662518', 'Moreta'),
#  ('A2NI9PAXZVW8HV', datetime.date(1995, 11, 14), 5, '0804106304', 'The Joy Luck Club'),
#  ('ATLV4W7XEJ3L6', datetime.date(1995, 9, 24), 5, '038532328X', 'The Face on the Milk Carton'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 14), 5, '034540288X', 'The Lost World'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0345370775', 'Jurassic Park'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0385323301', 'Where the Red Fern Grows'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0394588169', 'Jurassic Park'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0394588304', 'Jurassic Park'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0440412676', 'Where the Red Fern Grows'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0440505712', "The Nitpicker's Guide for Next Generation Trekkers, Vol. 1"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0553274295', 'Where the Red Fern Grows'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0553274295', 'Where the Red Fern Grows'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0590373579', 'Literature Guide'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0590373579', 'Literature Guide'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0671034758', 'The Star Trek Encyclopedia (Star Trek'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0671536079', 'The Star Trek Encyclopedia (Star Trek'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0671536095', 'The Star Trek Encyclopedia'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0807204684', 'Where the Red Fern Grows'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0881030589', 'Where the Red Fern Grows'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0671536109', 'Star Trek Chronology'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0345333926', 'Ringworld'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 2), 5, '0440506832', "The Nitpicker's Guide for Classic Trekkers"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 14), 5, '0931580587', "Ain't Nobody's Business If You Do "),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0553574132', 'Star Wars'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '080852125X', 'Sword of Shannara'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '0385285019', 'Illusions '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '052162942X', 'Citizens of the World '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0345378482', 'The Andromeda Strain'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0380731509', 'Wayside School is Falling Down'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0380754843', 'Wayside School is Falling Down'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0385302312', 'Dragonfly in Amber'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0385335970', 'Dragonfly in Amber'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0394415256', 'The Andromeda Strain'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0440215625', 'Dragonfly in Amber'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0553473301', 'Dragonfly in Amber'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0553714511', 'Dragonfly in Amber'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0688078680', 'Wayside School Is Falling Down'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '080720742X', 'Wayside School Is Falling Down'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0385302304', 'Outlander'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0440212561', 'Outlander'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0553473298', 'Outlander'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0553714538', 'Outlander'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 3), 5, '0878338020', 'Gardening With Native Plants of the South'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 17), 5, '0689718322', 'Dinosaur Dream'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 7, 23), 5, '4770017480', 'Handy Japanese'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 18), 5, '0385336535', 'Final Exit (Third Edition) '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 4), 5, '0399128964', 'Dune (Dune Chronicles (Econo-Clad Hardcover))'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 4), 5, '044100590X', 'Dune'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 4), 5, '0441172717', 'Dune (Dune Chronicles, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 4), 5, '0765342294', "Ender's Game (Ender)"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 4), 5, '0881036366', 'Dune (Dune Chronicles (Econo-Clad Hardcover))'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 4), 5, '1559949570', 'Dune Audio Collection'),
#  ('A30NVIKRN2FWQV', datetime.date(1996, 2, 4), 5, '0679751602', 'Mama Makes Up Her Mind '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 19), 5, '0425150429', 'Time Without End'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 25), 5, '1559273054', 'Illusions'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 19), 5, '087542791X', 'To Ride a Silver Broomstick'),
#  ('A7TD3MF4H5L7H', datetime.date(1996, 5, 10), 5, '094068747X', 'Psycho-Cybernetics (Audio Renaissance)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '0395911524', 'From Chocolate to Morphine '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '0380714752', 'The True Confessions of Charlotte Doyle (rack)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '053105893X', 'True Confessions Of Charlotte Doyle'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '0452273250', 'Down-Home Wholesome'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '0072487089', 'Drugs, Society and Human Behavior with PowerWeb'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '0452273250', 'Down-Home Wholesome'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '1881558029', "How to Really Love the One You're With!"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '1881558029', "How to Really Love the One You're With!"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '0312929722', 'Miracles Do Happen'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 5), 5, '0892833165', 'Miracles Do Happen'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 6), 5, '1881558029', "How to Really Love the One You're With!"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 10), 5, '0141304316', 'The Duplicate (Novel)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 26), 5, '034536676X', 'The World According to Garp'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 16), 5, '0131510517', 'UNIX System Administration Handbook (Bk\\CD ROM) (2nd Edition)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0192838881', "The Golden Ass (Oxford World's Classics (Paperback))"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0140119906', 'Love in the Time of Cholera (Penguin Great Books of the 20th Century)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0312857063', 'Stone of Tears (Sword of Truth, Book 2)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 26), 5, '0345418018', "The World According to Garp (Ballantine Reader's Circle)"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0374505322', 'The Golden Ass '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0375400699', "Love in the Time of Cholera (Everyman's Library (Cloth))"),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0441294677', 'God Emperor of Dune (Dune Chronicles, Book 4)'),
#  ('A1B2S8EFC1PYKE', datetime.date(1995, 9, 26), 5, '0440507545', 'Radical Honesty '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0812548094', 'Stone of Tears (Sword of Truth, Book 2)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 10), 5, '0380728621', "All God's Children"),
#  ('A1P66WOCE3X9ZO', datetime.date(1996, 2, 7), 5, '0061044695', 'Be Buried in the Rain'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 7), 5, '0803294271', 'Heaven Is a Playground'),
#  ('A1P66WOCE3X9ZO', datetime.date(1996, 2, 7), 5, '0425118312', 'Witch'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '1561007773', 'Stone of Tears (Sword of Truth, Book 2)'),
#  ('A3EJLAZ05FJNTT', datetime.date(1995, 11, 21), 5, '0373835590', 'These Old Shades'),
#  ('AS2FYO2A8WEMB', datetime.date(1996, 2, 8), 5, '0441813046', 'Titan'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 8), 5, '0060675535', 'Keeping Passover '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 8), 5, '0070504563', '201 Killer Cover Letters'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 9), 5, '0451451538', 'Vampire$'),
#  ('A2PLR225N5C0WD', datetime.date(1996, 2, 9), 5, '1563891050', 'The Sandman Vol. 6'),
#  ('A2PLR225N5C0WD', datetime.date(1996, 2, 9), 5, '1563891069', 'Fables and Reflections (Sandman, Book 6)'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 21), 5, '0374505322', 'The Golden Ass '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 10), 5, '0395716918', 'Piggie Pie!'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 10), 5, '0395866189', 'Piggie Pie!'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 10), 5, '0395900638', 'Piggie Pie!'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 10), 5, '0613036158', 'Piggie Pie!'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 10), 5, '0788190202', 'Bull Cook'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 11), 5, '0060921056', 'Letters from the Earth'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 11), 5, '0848817702', 'Letters from the Earth'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 11), 5, '1590070143', 'Letters from the Earth'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 11), 5, '1931056021', 'Letters from the Earth'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 11), 5, '1931056293', 'Letters from the Earth'),
#  ('A2A9ZIF2NEVS4W', datetime.date(1996, 2, 11), 5, '046509838X', 'Not Out of Africa'),
#  ('A3GZBNM72KUQ6R', datetime.date(1995, 11, 23), 5, '0882791354', 'Global Tyranny...Step by Step'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 12), 5, '155652241X', 'The Mole People'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 12), 5, '0226747875', 'Mystical Languages of Unsaying'),
#  ('A11ETZZ75RJC1W', datetime.date(1996, 2, 12), 5, '0879100737', 'Something Wonderful Right Away'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 12), 5, '0435086294', "The Dramatist's Toolkit"),
#  ('A1X6K8FD5AB8H0', datetime.date(1996, 2, 12), 5, '0764532391', 'Internet Secrets (... Secrets (IDG))'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 12), 5, '0451163931', 'Virtue of Selfishness'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 11, 25), 5, '0393036979', 'Titanic'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 13), 5, '0764110306', 'Guide to a Well-Behaved Parrot'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 13), 5, '1880646021', 'Project Mind'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 13), 5, '1880646021', 'Project Mind'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 13), 5, '1880646021', 'Project Mind'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 13), 5, '1880646021', 'Project Mind'),
#  ('A29JG1CS2NDMN5', datetime.date(1995, 11, 25), 5, '0590389246', 'Literature Guide'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 30), 5, '0060958324', 'Zen and the Art of Motorcycle Maintenance'),
#  ('A29JG1CS2NDMN5', datetime.date(1995, 11, 25), 5, '0689808828', 'Hatchet'),
#  ('A1D1BQFAEKS6JB', datetime.date(1996, 5, 16), 5, '0449208133', "Lucifer's Hammer"),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 14), 5, '0140250948', 'In the Lake of the Woods'),
#  ('AZHEOTHYGB34T', datetime.date(1996, 2, 14), 5, '0441094996', 'The Cat Who Walks Through Walls'),
#  ('A29JG1CS2NDMN5', datetime.date(1995, 11, 25), 5, '0689840926', 'Hatchet'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 15), 5, '1585742589', 'Monsters of the Sea'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 15), 5, '0140250948', 'In the Lake of the Woods'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 15), 5, '0940350254', 'Three Little Hawaiian Pigs and the Magic Shark'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 15), 5, '0823412199', 'The Life and Death of Crazy Horse'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 15), 5, '0822313405', 'Terminal Identity'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 16), 5, '0929661087', 'The Wellness Guide to Lifelong Fitness'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 16), 5, '0679728759', 'Blood Meridian '),
#  ('ATVPDKIKX0DER', datetime.date(1995, 9, 30), 5, '155927378X', 'Zen and the Art of Motorcycle Maintenance'),
#  ('ATVPDKIKX0DER', datetime.date(1995, 8, 20), 5, '0553380966', 'The Diamond Age '),
#  ('ATVPDKIKX0DER', datetime.date(1996, 2, 17), 5, '0380720868', 'Shadow of a Dark Queen (The Serpentwar Saga, Book 1)'),
#  ('ATVPDKIKX0DER', datetime.date(1996, 5, 16), 5, '0688147283', 'Peter and the Wolf')]

# %% [markdown]
# ## Conclusion: We can see that the columnar storage is faster!
